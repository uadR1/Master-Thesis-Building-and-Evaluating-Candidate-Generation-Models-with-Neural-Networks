# %% [markdown]
# # Loading Libraries

# %%
# Pandas & Numpy
import pandas as pd
import numpy as np 

# Visualization
import seaborn as sns 
from matplotlib import pyplot as plt 

# Tensorflow
import tensorflow as tf
from tensorflow import keras 

# Affinity Matrix 
from recommenders.datasets.sparse import AffinityMatrix

# Evaluation 
from recommenders.evaluation.python_evaluation import (
    precision_at_k,
    recall_at_k,
    ndcg_at_k,
    map_at_k
)
from sklearn.metrics import accuracy_score 

# Recomender Utilities
from recommenders.utils.timer import Timer
from recommenders.utils.constants import SEED as DEFAULT_SEED
from recommenders.utils.python_utils import binarize
from recommenders.datasets.python_splitters import numpy_stratified_split
from recommenders.datasets.split_utils import min_rating_filter_pandas

# Multi VAE Model
from recommenders.models.vae.multinomial_vae import Mult_VAE

# System & OS
import sys
import os

# Turn of Warnings for Readability 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Import & Read Dataset

# %%
# Read Train & Test Data
train = pd.read_csv("../../00_Data/online_retail_ratings_train.csv", index_col=0)
test = pd.read_csv("../../00_Data/online_retail_ratings_test.csv", index_col=0)

# %%
# Check Shapes
print("Shape of Train:", train.shape)
print("Shape of Test: \t", test.shape)
# Out:
# Shape of Train: (357692, 3)
# Shape of Test: 	 (89479, 3)

# %%
# Check Number of Unique Items and User in Train & Test 
print("Unique Users in Train:", train.CustomerID.nunique())
print("Unique Users in Test:", test.CustomerID.nunique())
print("Unique Items in Train:", train.StockCode.nunique())
print("Unique Items in Test:", test.StockCode.nunique())
# Out:
# Unique Users in Train: 3696
# Unique Users in Test: 3696
# Unique Items in Train: 2769
# Unique Items in Test: 2769

# %%
# Concatenate both Dataset again for further Data Preparation
df = pd.concat([train, test], axis=0)

# %%
# Change name of columns 
df = df.rename(columns={'StockCode':'itemID', 'CustomerID':'userID', 'purchased':'rating'})
df.columns
# Out:
# Index(['itemID', 'userID', 'rating'], dtype='object')

# %% [markdown]
# # Data Filtering

# %%
# Binarize the data (only keep ratings >= 0.5)
df_preferred = df[df['rating'] > 0]
print (df_preferred.shape)
df_low_rating = df[df['rating'] <= 0]


# Head of df_preferred
df_preferred.head(10)
# Out:
# (252517, 3)
#         itemID  userID  rating
# 125778    1526    2425       1
# 7621       170    4134       1
# 10277      197    2711       1
# 134246    1592    1587       1
# 1846        43    3135       1
# 6252       166    1476       1
# 113247    1437     920       1
# 226836    2776     568       2
# 68565      999    3328       2
# 250848    3303    2967       1

# %%
# Head of df_low_rating
df_low_rating.head(10)
# Out:
#         itemID  userID  rating
# 370557    1551     223      -1
# 440452    2043    2392      -1
# 428223    1756    1936      -1
# 285547    2043      69      -1
# 302095     399      48      -1
# 317834    3249    1554      -1
# 257638    1931    1632      -2
# 339503    2079     431      -1
# 422694    1092    2473      -1
# 391314    1838     448      -1

# %%
# Keep users who clicked on at least 5 items
df = min_rating_filter_pandas(df_preferred, min_rating=5, filter_by="user")

# Keep movies that were clicked on by at least on 1 user
df = min_rating_filter_pandas(df, min_rating=1, filter_by="item")

# %%
# Obtain both usercount and itemcount after filtering
usercount = df[['userID']].groupby('userID', as_index = False).size()
itemcount = df[['itemID']].groupby('itemID', as_index = False).size()

# Compute sparsity after filtering
sparsity = 1. * df.shape[0] / (usercount.shape[0] * itemcount.shape[0])

print("After filtering, there are %d interactions between %d users and %d items (sparsity: %.3f%%)" % 
      (df.shape[0], usercount.shape[0], itemcount.shape[0], sparsity * 100))
# Out:
# After filtering, there are 252513 interactions between 3686 users and 2769 items (sparsity: 2.474%)

# %% [markdown]
# # Split Data

# %%
unique_users = sorted(df.userID.unique())
np.random.seed(1)
unique_users = np.random.permutation(unique_users)

# %%
# Create train/validation/test users
n_users = len(unique_users)
print("Number of unique users:", n_users)

train_users = unique_users[:(n_users - 750 * 2)]
print("\nNumber of training users:", len(train_users))

val_users = unique_users[(n_users - 750 * 2) : (n_users - 750)]
print("\nNumber of validation users:", len(val_users))

test_users = unique_users[(n_users - 750):]
print("\nNumber of test users:", len(test_users))
# Out:
# Number of unique users: 3686
#
# Number of training users: 2186
#
# Number of validation users: 750
#
# Number of test users: 750

# %%
# For training set keep only users that are in train_users list
train_set = df.loc[df['userID'].isin(train_users)]
print("Number of training observations: ", train_set.shape[0])

# For validation set keep only users that are in val_users list
val_set = df.loc[df['userID'].isin(val_users)]
print("\nNumber of validation observations: ", val_set.shape[0])

# For test set keep only users that are in test_users list
test_set = df.loc[df['userID'].isin(test_users)]
print("\nNumber of test observations: ", test_set.shape[0])
# Out:
# Number of training observations:  147724
#
# Number of validation observations:  52353
#
# Number of test observations:  52436

# %%
# Obtain list of unique items used in training set
unique_train_items = pd.unique(train_set['itemID'])
print("Number of unique items that consumed in training set", unique_train_items.size)
# Out:
# Number of unique items that consumed in training set 2769

# %%
# For validation set keep only items that used in training set
val_set = val_set.loc[val_set['itemID'].isin(unique_train_items)]
print("Number of validation observations after filtering: ", val_set.shape[0])

# For test set keep only movies items used in training set
test_set = test_set.loc[test_set['itemID'].isin(unique_train_items)]
print("\nNumber of test observations after filtering: ", test_set.shape[0])
# Out:
# Number of validation observations after filtering:  52353
#
# Number of test observations after filtering:  52436

# %%
test_set.shape[0] / (train_set.shape[0] + val_set.shape[0] + test_set.shape[0])
# Out:
# 0.20765663549995445

# %% [markdown]
# # Click Matrix Generation

# %%
# Instantiate the sparse matrix generation for train, validation and test sets
# use list of unique items from training set for all sets
am_train = AffinityMatrix(df=train_set, items_list=unique_train_items)

am_val = AffinityMatrix(df=val_set, items_list=unique_train_items)

am_test = AffinityMatrix(df=test_set, items_list=unique_train_items)

# %%
# Obtain the sparse matrix for train, validation and test sets
train_data, _, _ = am_train.gen_affinity_matrix()
print(train_data.shape)

val_data, val_map_users, val_map_items = am_val.gen_affinity_matrix()
print(val_data.shape)

test_data, test_map_users, test_map_items = am_test.gen_affinity_matrix()
print(test_data.shape)
# Out:
# (2186, 2769)
# (750, 2769)
# (750, 2769)

# %%
# Split validation and test data into training and testing parts
val_data_tr, val_data_te = numpy_stratified_split(val_data, ratio=0.75, seed=1)
test_data_tr, test_data_te = numpy_stratified_split(test_data, ratio=0.75, seed=1)

# %%
# Binarize train, validation and test data
train_data = binarize(a=train_data, threshold=0.5)
val_data = binarize(a=val_data, threshold=0.5)
test_data = binarize(a=test_data, threshold=0.5)

# %%
# Binarize validation data: training part  
val_data_tr = binarize(a=val_data_tr, threshold=0.5)

# Binarize validation data: testing part (save non-binary version in the separate object, will be used for calculating NDCG)
val_data_te_ratings = val_data_te.copy()
val_data_te = binarize(a=val_data_te, threshold=0.5)

# %%
# Binarize test data: training part 
test_data_tr = binarize(a=test_data_tr, threshold=0.5)

# Binarize test data: testing part (save non-binary version in the separate object, will be used for calculating NDCG)
test_data_te_ratings = test_data_te.copy()
test_data_te = binarize(a=test_data_te, threshold=0.5)

# %% [markdown]
#  # Shapes and Dimensions after Data Preparation

# %%
# Interactions in Train & Test of Val & Test 
print("Interactions in Validation Training",val_data_tr.sum())
print("Interactions in Validation Test",val_data_te.sum())
print("Interactions in Test Training",test_data_tr.sum())
print("Interactions in Test Test",test_data_te.sum())
# Out:
# Interactions in Validation Training 39277.0
# Interactions in Validation Test 13076.0
# Interactions in Test Training 39323.0
# Interactions in Test Test 13113.0

# %%
np.unique(test_data_tr)
# Out:
# array([0., 1.])

# %%
np.unique(train_data)
# Out:
# array([0., 1.])

# %%
np.unique(val_data)
# Out:
# array([0., 1.])

# %%
np.unique(val_data_tr)
# Out:
# array([0., 1.])

# %%
np.unique(test_data_te_ratings)
# Out:
# array([0, 1, 2])

# %%
np.unique(val_data_te_ratings)
# Out:
# array([0, 1, 2])

# %% [markdown]
# # Baseline Model Multi VAE

# %%
from tensorflow.python.framework.ops import disable_eager_execution

disable_eager_execution()

# %%
from tempfile import TemporaryDirectory

tmp_dir = TemporaryDirectory()
WEIGHTS_PATH = os.path.join(tmp_dir.name, "svae_weights.hdf5")

# %%
model_without_anneal = Mult_VAE(n_users=train_data.shape[0], # Number of unique users in the training set
                                   original_dim=train_data.shape[1], # Number of unique items in the training set
                                   intermediate_dim=1000, 
                                   latent_dim=50, 
                                   n_epochs=50, 
                                   batch_size=50, 
                                   k=100,
                                   verbose=0,
                                   seed=1,
                                   drop_encoder=0.5,
                                   drop_decoder=0.5,
                                   annealing=False,
                                   beta=1.0,
                                   save_path=WEIGHTS_PATH
                                   )

# %%
with Timer() as t:
    model_without_anneal.fit(x_train=train_data, 
                        x_valid=val_data,
                        x_val_tr=val_data_tr, 
                        x_val_te=val_data_te_ratings, # with the original ratings 
                        mapper=am_val)
print("Took {} seconds for training.".format(t))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 2
#       1 with Timer() as t:
# ----> 2     model_without_anneal.fit(x_train=train_data,
#       3                         x_valid=val_data,
#       4                         x_val_tr=val_data_tr,
#       5                         x_val_te=val_data_te_ratings, # with the original ratings
#       6                         mapper=am_val)
#       7 print("Took {} seconds for training.".format(t))
#
# File ~/opt/anaconda3/envs/recom/lib/python3.9/site-packages/recommenders/models/vae/multinomial_vae.py:443, in Mult_VAE.fit(self, x_train, x_valid, x_val_tr, x_val_te, mapper)
#     440     self.ls_beta = anneal.get_data()
#     442 else:
# --> 443     self.model.fit_generator(
#     444         generator=self.nn_batch_generator(x_train),
#     445         steps_per_epoch=self.number_of_batches,
#     446         epochs=self.n_epochs,
#     447         verbose=self.verbose,
#     448         callbacks=[metrics, history, self.reduce_lr],
#     449         validation_data=(x_valid, x_valid),
#     450     )
#     452 # save lists
#     453 self.train_loss = history.losses
#
# File ~/opt/anaconda3/envs/recom/lib/python3.9/site-packages/tensorflow/python/keras/engine/training_v1.py:1243, in Model.fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1234 """Fits the model on data yielded batch-by-batch by a Python generator.
#    1235
#    1236 DEPRECATED:
#    1237   `Model.fit` now supports generators, so there is no longer any need to use
#    1238   this endpoint.
#    1239 """
#    1240 warnings.warn('`model.fit_generator` is deprecated and '
#    1241               'will be removed in a future version. '
#    1242               'Please use `Model.fit`, which supports generators.')
# -> 1243 return self.fit(
#    1244     generator,
#    1245     steps_per_epoch=steps_per_epoch,
#    1246     epochs=epochs,
#    1247     verbose=verbose,
#    1248     callbacks=callbacks,
#    1249     validation_data=validation_data,
#    1250     validation_steps=validation_steps,
#    1251     validation_freq=validation_freq,
#    1252     class_weight=class_weight,
#    1253     max_queue_size=max_queue_size,
#    1254     workers=workers,
#    1255     use_multiprocessing=use_multiprocessing,
#    1256     shuffle=shuffle,
#    1257     initial_epoch=initial_epoch)
#
# File ~/opt/anaconda3/envs/recom/lib/python3.9/site-packages/tensorflow/python/keras/engine/training_v1.py:789, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     786 self._check_call_args('fit')
#     788 func = self._select_training_loop(x)
# --> 789 return func.fit(
#     790     self,
#     791     x=x,
#     792     y=y,
#     793     batch_size=batch_size,
#     794     epochs=epochs,
#     795     verbose=verbose,
#     796     callbacks=callbacks,
#     797     validation_split=validation_split,
#     798     validation_data=validation_data,
#     799     shuffle=shuffle,
#     800     class_weight=class_weight,
#     801     sample_weight=sample_weight,
#     802     initial_epoch=initial_epoch,
#     803     steps_per_epoch=steps_per_epoch,
#     804     validation_steps=validation_steps,
#     805     validation_freq=validation_freq,
#     806     max_queue_size=max_queue_size,
#     807     workers=workers,
#     808     use_multiprocessing=use_multiprocessing)
#
# File ~/opt/anaconda3/envs/recom/lib/python3.9/site-packages/tensorflow/python/keras/engine/training_generator_v1.py:577, in GeneratorOrSequenceTrainingLoop.fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing)
#     574 model._validate_or_infer_batch_size(batch_size, steps_per_epoch, x)
#     575 training_utils_v1.check_generator_arguments(
#     576     y, sample_weight, validation_split=validation_split)
# --> 577 return fit_generator(
#     578     model,
#     579     x,
#     580     steps_per_epoch=steps_per_epoch,
#     581     epochs=epochs,
#     582     verbose=verbose,
#     583     callbacks=callbacks,
#     584     validation_data=validation_data,
#     585     validation_steps=validation_steps,
#     586     validation_freq=validation_freq,
#     587     class_weight=class_weight,
#     588     max_queue_size=max_queue_size,
#     589     workers=workers,
#     590     use_multiprocessing=use_multiprocessing,
#     591     shuffle=shuffle,
#     592     initial_epoch=initial_epoch,
#     593     steps_name='steps_per_epoch')
#
# File ~/opt/anaconda3/envs/recom/lib/python3.9/site-packages/tensorflow/python/keras/engine/training_generator_v1.py:259, in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     256 callbacks._call_batch_hook(mode, 'begin', step, batch_logs)
#     258 is_deferred = not model._is_compiled
# --> 259 batch_outs = batch_function(*batch_data)
#     260 if not isinstance(batch_outs, list):
#     261   batch_outs = [batch_outs]
#
# File ~/opt/anaconda3/envs/recom/lib/python3.9/site-packages/tensorflow/python/keras/engine/training_v1.py:1088, in Model.train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1086   self._update_sample_weight_modes(sample_weights=sample_weights)
#    1087   self._make_train_function()
# -> 1088   outputs = self.train_function(ins)  # pylint: disable=not-callable
#    1090 if reset_metrics:
#    1091   self.reset_metrics()
#
# File ~/opt/anaconda3/envs/recom/lib/python3.9/site-packages/tensorflow/python/keras/backend.py:3956, in GraphExecutionFunction.__call__(self, inputs)
#    3950 if (self._callable_fn is None or feed_arrays != self._feed_arrays or
#    3951     symbol_vals != self._symbol_vals or
#    3952     feed_symbols != self._feed_symbols or self.fetches != self._fetches or
#    3953     session != self._session):
#    3954   self._make_callable(feed_arrays, feed_symbols, symbol_vals, session)
# -> 3956 fetched = self._callable_fn(*array_vals,
#    3957                             run_metadata=self.run_metadata)
#    3958 self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3959 output_structure = nest.pack_sequence_as(
#    3960     self._outputs_structure,
#    3961     fetched[:len(self.outputs)],
#    3962     expand_composites=True)
#
# File ~/opt/anaconda3/envs/recom/lib/python3.9/site-packages/tensorflow/python/client/session.py:1480, in BaseSession._Callable.__call__(self, *args, **kwargs)
#    1478 try:
#    1479   run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
# -> 1480   ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1481                                          self._handle, args,
#    1482                                          run_metadata_ptr)
#    1483   if run_metadata:
#    1484     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
model_without_anneal.display_metrics()

# %%
# Use k = 10
with Timer() as t:
    # Model prediction on the training part of test set 
    top_k =  model_without_anneal.recommend_k_items(x=test_data_tr,
                                                    k=10,
                                                    remove_seen=True
                                                    )

    # Convert sparse matrix back to df
    top_k_df = am_test.map_back_sparse(top_k, kind='prediction')
    test_df = am_test.map_back_sparse(test_data_te_ratings, kind='ratings') # use test_data_te_, with the original ratings
    
print("Took {} seconds for prediction.".format(t))

# Use the ranking metrics for evaluation
eval_map_1 = map_at_k(test_df, top_k_df, col_prediction='prediction', k=10)
eval_ndcg_1 = ndcg_at_k(test_df, top_k_df, col_prediction='prediction', k=10)
eval_precision_1 = precision_at_k(test_df, top_k_df, col_prediction='prediction', k=10)
eval_recall_1 = recall_at_k(test_df, top_k_df, col_prediction='prediction', k=10)

print("MAP@10:\t\t%f" % eval_map_1,
      "NDCG@10:\t%f" % eval_ndcg_1,
      "Precision@10:\t%f" % eval_precision_1,
      "Recall@10: \t%f" % eval_recall_1, sep='\n')
# Out:
# Took 0.6928 seconds for prediction.
# MAP@10:		0.035560
# NDCG@10:	0.138120
# Precision@10:	0.115067
# Recall@10: 	0.081049

# %%
test_df.describe()
# Out:
#              userID        itemID        rating
# count  13113.000000  13113.000000  13113.000000
# mean    2192.521925   1550.841913      1.234424
# std     1281.629891    811.215250      0.423654
# min       17.000000      0.000000      1.000000
# 25%     1104.000000    936.000000      1.000000
# 50%     2091.000000   1520.000000      1.000000
# 75%     3348.000000   2089.000000      1.000000
# max     4357.000000   3625.000000      2.000000

# %%
top_k_df.describe()
# Out:
#             userID       itemID   prediction
# count  7500.000000  7500.000000  7500.000000
# mean   2159.444000  1649.438267     2.832940
# std    1282.586385   831.219480     0.442999
# min      17.000000     7.000000     1.230721
# 25%    1037.000000  1039.000000     2.524217
# 50%    2074.500000  1570.000000     2.790007
# 75%    3305.000000  2133.000000     3.085558
# max    4357.000000  3342.000000     5.235447

# %% [markdown]
# # Hyperparameter Tuning

# %%
# Set up Parameters
intermediate_dimension = [600, 800, 1000, 1200, 1400] 
latent_dimension = [50, 70, 90] 
batch_sizes = [50]
anneal_status = [True, False]

# Initiate Lists for Assessment
recall_10 = []
recall_20 = []
precision_10 = []
precision_20 = []
int_dimensions = []
lt_dimensions = []
anneal = []
batch = []

for i in intermediate_dimension:
    for l in latent_dimension:
        for b in batch_sizes:
            for a in anneal_status:
                try:
                    del(model)
                except:
                    pass
                
                # Initiate Model 
                if a == True:
                    model = Mult_VAE(n_users=train_data.shape[0],
                                        original_dim=train_data.shape[1],
                                        intermediate_dim=i,
                                        latent_dim=l,
                                        n_epochs=100,
                                        batch_size=b,
                                        k=100,
                                        verbose=0,
                                        seed=1,
                                        save_path=WEIGHTS_PATH,
                                        drop_encoder=0.5,
                                        drop_decoder=0.5,
                                        annealing=True,
                                        anneal_cap=1.0)
                else:
                    model = Mult_VAE(n_users=train_data.shape[0], # Number of unique users in the training set
                                        original_dim=train_data.shape[1], # Number of unique items in the training set
                                        intermediate_dim=i, 
                                        latent_dim=l, 
                                        n_epochs=100, 
                                        batch_size=b, 
                                        k=100,
                                        verbose=0,
                                        seed=1,
                                        drop_encoder=0.5,
                                        drop_decoder=0.5,
                                        annealing=False,
                                        beta=1.0,
                                        save_path=WEIGHTS_PATH)
                
                # Fit model
                model.fit(x_train=train_data,
                        x_valid=val_data,
                        x_val_tr=val_data_tr,
                        x_val_te=val_data_te_ratings,
                        mapper=am_val)
            
                # Model prediction on the training part of test set K = 10  
                top_k_10 =  model.recommend_k_items(x=test_data_tr,
                                                    k=10,
                                                    remove_seen=True)

                # Convert sparse matrix back to df
                top_k_df_10 = am_test.map_back_sparse(top_k_10, kind='prediction')
                test_df = am_test.map_back_sparse(test_data_te_ratings, kind='ratings') # use test_data_te_, with the original ratings
    

                # Use the ranking metrics for evaluation
                eval_precision_10 = precision_at_k(test_df, top_k_df_10, col_prediction='prediction', k=10)
                eval_recall_10 = recall_at_k(test_df, top_k_df_10, col_prediction='prediction', k=10)

                # Print intermediate Status for Recall@10
                print("Recall@10 for Intermediate Dim: ", i, "Latent Dim: ", l, "Batch size: ", b, "Annealing: ", a, ":\t", eval_recall_10)
                
                #Model prediction on the training part of test set K = 20  
                top_k_20 =  model.recommend_k_items(x=test_data_tr,
                                                    k=20,
                                                    remove_seen=True)

                # Convert sparse matrix back to df
                top_k_df_20 = am_test.map_back_sparse(top_k_20, kind='prediction')
    

                # Use the ranking metrics for evaluation
                eval_precision_20 = precision_at_k(test_df, top_k_df_20, col_prediction='prediction', k=20)
                eval_recall_20 = recall_at_k(test_df, top_k_df_20, col_prediction='prediction', k=20)
                
                # Print intermediate Status for Recall@20
                print("Recall@20 for Intermediate Dim: ", i, "Latent Dim: ", l, "Batch size: ", b, "Annealing: ", a, ":\t", eval_recall_20)
                
                # Append Lists
                recall_10.append(eval_recall_10)
                recall_20.append(eval_recall_20)
                precision_10.append(eval_precision_10)
                precision_20.append(eval_precision_20)
                int_dimensions.append(i)
                lt_dimensions.append(l)
                anneal.append(a)
                batch.append(b)
# Out:
# Recall@10 for Intermediate Dim:  600 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.10367496400846558
# Recall@20 for Intermediate Dim:  600 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.15838124390700198
# Recall@10 for Intermediate Dim:  600 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.08146165927187403
# Recall@20 for Intermediate Dim:  600 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.12233585484246513
# Recall@10 for Intermediate Dim:  600 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.09898245987096055
# Recall@20 for Intermediate Dim:  600 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.1527668750636058
# Recall@10 for Intermediate Dim:  600 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.07654826057388896
# Recall@20 for Intermediate Dim:  600 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.12217314609305996
# Recall@10 for Intermediate Dim:  600 Latent Dim:  90 Batch size:  50 Annealing:  True :	 0.1012361156790337
# Recall@20 for Intermediate Dim:  600 Latent Dim:  90 Batch size:  50 Annealing:  True :	 0.15278020956290309
# Recall@10 for Intermediate Dim:  600 Latent Dim:  90 Batch size:  50 Annealing:  False :	 0.07002780429634313
# Recall@20 for Intermediate Dim:  600 Latent Dim:  90 Batch size:  50 Annealing:  False :	 0.12418992102645424
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0226s vs `on_train_batch_end` time: 0.0253s). Check your callbacks.
# Recall@10 for Intermediate Dim:  800 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.1046132134981246
# Recall@20 for Intermediate Dim:  800 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.15659314933576146
# Recall@10 for Intermediate Dim:  800 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.07385714884463584
# Recall@20 for Intermediate Dim:  800 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.12127769721133128
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0320s vs `on_train_batch_end` time: 0.0362s). Check your callbacks.
# Recall@10 for Intermediate Dim:  800 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.09717844774681104
# Recall@20 for Intermediate Dim:  800 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.15639320223234363
# Recall@10 for Intermediate Dim:  800 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.07772210264801659
# Recall@20 for Intermediate Dim:  800 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.1226011455018169
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0246s vs `on_train_batch_end` time: 0.0371s). Check your callbacks.
# Recall@10 for Intermediate Dim:  800 Latent Dim:  90 Batch size:  50 Annealing:  True :	 0.0989120118545615
# Recall@20 for Intermediate Dim:  800 Latent Dim:  90 Batch size:  50 Annealing:  True :	 0.1541288651845521
# Recall@10 for Intermediate Dim:  800 Latent Dim:  90 Batch size:  50 Annealing:  False :	 0.0721441061628
# Recall@20 for Intermediate Dim:  800 Latent Dim:  90 Batch size:  50 Annealing:  False :	 0.12036807722182297
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0281s vs `on_train_batch_end` time: 0.0451s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.10397764613349852
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.16253787511265835
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.07918897031674356
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.12175965814163867
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0318s vs `on_train_batch_end` time: 0.0567s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.09901051863511583
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.15926248703876456
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.07709322014030905
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.1258865875405827
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0292s vs `on_train_batch_end` time: 0.0551s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  90 Batch size:  50 Annealing:  True :	 0.09559033481471714
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  90 Batch size:  50 Annealing:  True :	 0.16122869487580418
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  90 Batch size:  50 Annealing:  False :	 0.07432215387252755
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  90 Batch size:  50 Annealing:  False :	 0.12538513586089733
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0403s vs `on_train_batch_end` time: 0.0616s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.11071606238257944
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.16499444529373555
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.07628323527100948
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.125270487670797
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0347s vs `on_train_batch_end` time: 0.0741s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.10905680300150306
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.16078293714083836
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.0730873657061025
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.1237810494155316
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0379s vs `on_train_batch_end` time: 0.0729s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  90 Batch size:  50 Annealing:  True :	 0.10387335448996225
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  90 Batch size:  50 Annealing:  True :	 0.15516891045661677
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  90 Batch size:  50 Annealing:  False :	 0.07070742681073801
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  90 Batch size:  50 Annealing:  False :	 0.12050303793667767
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0411s vs `on_train_batch_end` time: 0.0810s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.10590804675754807
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.15998063730656864
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.0758470932840038
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.1239509896471389
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0389s vs `on_train_batch_end` time: 0.0877s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.10148431122197701
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.1608429779006671
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.07650917353748805
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.12223100633461761
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0474s vs `on_train_batch_end` time: 0.1082s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  90 Batch size:  50 Annealing:  True :	 0.10067990620517772
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  90 Batch size:  50 Annealing:  True :	 0.1540272539197443
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  90 Batch size:  50 Annealing:  False :	 0.07341496499969231
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  90 Batch size:  50 Annealing:  False :	 0.1230281598761702

# %%
# Create Dataframe out of the Results of the Hyperparameter Tuning 
df_tuning_initial = pd.DataFrame({
    "intermediate_dimensions": int_dimensions,
    "latent_dimensions": lt_dimensions,
    "annealing": anneal,
    "batch_size": batch,
    "recall@10": recall_10,
    "recall@20": recall_20,
    "precision@10":precision_10,
    "precision@20":precision_20
})
# Sort Values by recall@10 
df_tuning_initial.sort_values(by='recall@10', ascending=False)
# Out:
#     intermediate_dimensions  latent_dimensions  annealing  batch_size  \
# 18                     1200                 50       True          50
# 20                     1200                 70       True          50
# 24                     1400                 50       True          50
# 6                       800                 50       True          50
# 12                     1000                 50       True          50
# 22                     1200                 90       True          50
# 0                       600                 50       True          50
# 26                     1400                 70       True          50
# 4                       600                 90       True          50
# 28                     1400                 90       True          50
# 14                     1000                 70       True          50
# 2                       600                 70       True          50
# 10                      800                 90       True          50
# 8                       800                 70       True          50
# 16                     1000                 90       True          50
# 1                       600                 50      False          50
# 13                     1000                 50      False          50
# 9                       800                 70      False          50
# 15                     1000                 70      False          50
# 3                       600                 70      False          50
# 27                     1400                 70      False          50
# 19                     1200                 50      False          50
# 25                     1400                 50      False          50
# 17                     1000                 90      False          50
# 7                       800                 50      False          50
# 29                     1400                 90      False          50
# 21                     1200                 70      False          50
# 11                      800                 90      False          50
# 23                     1200                 90      False          50
# 5                       600                 90      False          50
#
#     recall@10  recall@20  precision@10  precision@20
# 18   0.110716   0.164994      0.148933      0.115867
# 20   0.109057   0.160783      0.144267      0.114133
# 24   0.105908   0.159981      0.143600      0.112600
# 6    0.104613   0.156593      0.140667      0.110867
# 12   0.103978   0.162538      0.141467      0.113667
# 22   0.103873   0.155169      0.137333      0.109200
# 0    0.103675   0.158381      0.140667      0.111933
# 26   0.101484   0.160843      0.142533      0.113467
# 4    0.101236   0.152780      0.137600      0.109333
# 28   0.100680   0.154027      0.134133      0.107333
# 14   0.099011   0.159262      0.134933      0.111733
# 2    0.098982   0.152767      0.134667      0.109400
# 10   0.098912   0.154129      0.136000      0.107933
# 8    0.097178   0.156393      0.139067      0.111467
# 16   0.095590   0.161229      0.133067      0.110933
# 1    0.081462   0.122336      0.118800      0.090800
# 13   0.079189   0.121760      0.115067      0.093733
# 9    0.077722   0.122601      0.112667      0.091067
# 15   0.077093   0.125887      0.114400      0.092800
# 3    0.076548   0.122173      0.110000      0.091133
# 27   0.076509   0.122231      0.111600      0.089867
# 19   0.076283   0.125270      0.115067      0.093333
# 25   0.075847   0.123951      0.115733      0.091733
# 17   0.074322   0.125385      0.107867      0.091400
# 7    0.073857   0.121278      0.114400      0.093200
# 29   0.073415   0.123028      0.111333      0.089267
# 21   0.073087   0.123781      0.110800      0.094933
# 11   0.072144   0.120368      0.107733      0.089000
# 23   0.070707   0.120503      0.101200      0.090400
# 5    0.070028   0.124190      0.106133      0.092133

# %%
# Check Average Performance of Latent Dimensions
df_tuning_initial.groupby("latent_dimensions")['recall@10'].mean()
# Out:
# latent_dimensions
# 50    0.091553
# 70    0.088667
# 90    0.086091
# Name: recall@10, dtype: float64

# %% [markdown]
# # Hyperparameter Tuning 2.0

# %%
# Set up Parameters
intermediate_dimension = [1100, 1200, 1300, 1400, 1500] 
latent_dimension = [30, 40, 50, 60, 70] 
batch_sizes = [50]
anneal_status = [True, False]

# Initiate Lists for Assessment
recall_10 = []
recall_20 = []
precision_10 = []
precision_20 = []
int_dimensions = []
lt_dimensions = []
anneal = []
batch = []

for i in intermediate_dimension:
    for l in latent_dimension:
        for b in batch_sizes:
            for a in anneal_status:
                try:
                    del(model)
                except:
                    pass
                
                # Initiate Model 
                if a == True:
                    model = Mult_VAE(n_users=train_data.shape[0],
                                        original_dim=train_data.shape[1],
                                        intermediate_dim=i,
                                        latent_dim=l,
                                        n_epochs=100,
                                        batch_size=b,
                                        k=100,
                                        verbose=0,
                                        seed=1,
                                        save_path=WEIGHTS_PATH,
                                        drop_encoder=0.5,
                                        drop_decoder=0.5,
                                        annealing=True,
                                        anneal_cap=1.0)
                else:
                    model = Mult_VAE(n_users=train_data.shape[0], # Number of unique users in the training set
                                        original_dim=train_data.shape[1], # Number of unique items in the training set
                                        intermediate_dim=i, 
                                        latent_dim=l, 
                                        n_epochs=100, 
                                        batch_size=b, 
                                        k=100,
                                        verbose=0,
                                        seed=1,
                                        drop_encoder=0.5,
                                        drop_decoder=0.5,
                                        annealing=False,
                                        beta=1.0,
                                        save_path=WEIGHTS_PATH)
                
                # Fit model
                model.fit(x_train=train_data,
                        x_valid=val_data,
                        x_val_tr=val_data_tr,
                        x_val_te=val_data_te_ratings,
                        mapper=am_val)
            
                # Model prediction on the training part of test set K = 10  
                top_k_10 =  model.recommend_k_items(x=test_data_tr,
                                                    k=10,
                                                    remove_seen=True)

                # Convert sparse matrix back to df
                top_k_df_10 = am_test.map_back_sparse(top_k_10, kind='prediction')
                test_df = am_test.map_back_sparse(test_data_te_ratings, kind='ratings') # use test_data_te_, with the original ratings
    

                # Use the ranking metrics for evaluation
                eval_precision_10 = precision_at_k(test_df, top_k_df_10, col_prediction='prediction', k=10)
                eval_recall_10 = recall_at_k(test_df, top_k_df_10, col_prediction='prediction', k=10)

                # Print intermediate Status for Recall@10
                print("Recall@10 for Intermediate Dim: ", i, "Latent Dim: ", l, "Batch size: ", b, "Annealing: ", a, ":\t", eval_recall_10)
                
                #Model prediction on the training part of test set K = 20  
                top_k_20 =  model.recommend_k_items(x=test_data_tr,
                                                    k=20,
                                                    remove_seen=True)

                # Convert sparse matrix back to df
                top_k_df_20 = am_test.map_back_sparse(top_k_20, kind='prediction')
    

                # Use the ranking metrics for evaluation
                eval_precision_20 = precision_at_k(test_df, top_k_df_20, col_prediction='prediction', k=20)
                eval_recall_20 = recall_at_k(test_df, top_k_df_20, col_prediction='prediction', k=20)
                
                # Print intermediate Status for Recall@20
                print("Recall@20 for Intermediate Dim: ", i, "Latent Dim: ", l, "Batch size: ", b, "Annealing: ", a, ":\t", eval_recall_20)
                
                # Append Lists
                recall_10.append(eval_recall_10)
                recall_20.append(eval_recall_20)
                precision_10.append(eval_precision_10)
                precision_20.append(eval_precision_20)
                int_dimensions.append(i)
                lt_dimensions.append(l)
                anneal.append(a)
                batch.append(b)
# Out:
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0375s vs `on_train_batch_end` time: 0.1147s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1100 Latent Dim:  30 Batch size:  50 Annealing:  True :	 0.10768801922004201
# Recall@20 for Intermediate Dim:  1100 Latent Dim:  30 Batch size:  50 Annealing:  True :	 0.1580725763391716
# Recall@10 for Intermediate Dim:  1100 Latent Dim:  30 Batch size:  50 Annealing:  False :	 0.07626144879865941
# Recall@20 for Intermediate Dim:  1100 Latent Dim:  30 Batch size:  50 Annealing:  False :	 0.13373560621393274
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0367s vs `on_train_batch_end` time: 0.1122s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1100 Latent Dim:  40 Batch size:  50 Annealing:  True :	 0.10695524004393106
# Recall@20 for Intermediate Dim:  1100 Latent Dim:  40 Batch size:  50 Annealing:  True :	 0.1618372233714736
# Recall@10 for Intermediate Dim:  1100 Latent Dim:  40 Batch size:  50 Annealing:  False :	 0.07543295435004511
# Recall@20 for Intermediate Dim:  1100 Latent Dim:  40 Batch size:  50 Annealing:  False :	 0.12222122058254509
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0315s vs `on_train_batch_end` time: 0.1103s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1100 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.10410519272766172
# Recall@20 for Intermediate Dim:  1100 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.1597338337489251
# Recall@10 for Intermediate Dim:  1100 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.07137500829455384
# Recall@20 for Intermediate Dim:  1100 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.11811109090658223
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0319s vs `on_train_batch_end` time: 0.1211s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1100 Latent Dim:  60 Batch size:  50 Annealing:  True :	 0.1061409717020349
# Recall@20 for Intermediate Dim:  1100 Latent Dim:  60 Batch size:  50 Annealing:  True :	 0.15535986695237267
# Recall@10 for Intermediate Dim:  1100 Latent Dim:  60 Batch size:  50 Annealing:  False :	 0.08203353713853667
# Recall@20 for Intermediate Dim:  1100 Latent Dim:  60 Batch size:  50 Annealing:  False :	 0.11913949725625635
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0332s vs `on_train_batch_end` time: 0.1354s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1100 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.10396255713550571
# Recall@20 for Intermediate Dim:  1100 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.1668129902249941
# Recall@10 for Intermediate Dim:  1100 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.07659441087742541
# Recall@20 for Intermediate Dim:  1100 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.12377518790828256
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0368s vs `on_train_batch_end` time: 0.1312s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  30 Batch size:  50 Annealing:  True :	 0.11074917681446907
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  30 Batch size:  50 Annealing:  True :	 0.16649574483752863
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  30 Batch size:  50 Annealing:  False :	 0.077392229837145
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  30 Batch size:  50 Annealing:  False :	 0.12894728291031135
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0363s vs `on_train_batch_end` time: 0.1335s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  40 Batch size:  50 Annealing:  True :	 0.1070052343535813
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  40 Batch size:  50 Annealing:  True :	 0.17313747832899762
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  40 Batch size:  50 Annealing:  False :	 0.0764726989080961
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  40 Batch size:  50 Annealing:  False :	 0.12355736597734701
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0355s vs `on_train_batch_end` time: 0.1424s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.10369452974273592
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.16147244848899212
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.07617875033375504
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.12599096808307206
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0344s vs `on_train_batch_end` time: 0.1538s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  60 Batch size:  50 Annealing:  True :	 0.10508598212180759
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  60 Batch size:  50 Annealing:  True :	 0.16399472578897467
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  60 Batch size:  50 Annealing:  False :	 0.07632693196202481
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  60 Batch size:  50 Annealing:  False :	 0.12290594143195303
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0383s vs `on_train_batch_end` time: 0.1581s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.10294185753745728
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.1546562789975047
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.07216754394896611
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.12221915882436671
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0370s vs `on_train_batch_end` time: 0.1637s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1300 Latent Dim:  30 Batch size:  50 Annealing:  True :	 0.10646802760988598
# Recall@20 for Intermediate Dim:  1300 Latent Dim:  30 Batch size:  50 Annealing:  True :	 0.1600160212007779
# Recall@10 for Intermediate Dim:  1300 Latent Dim:  30 Batch size:  50 Annealing:  False :	 0.07254986759561012
# Recall@20 for Intermediate Dim:  1300 Latent Dim:  30 Batch size:  50 Annealing:  False :	 0.13210746637026113
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0356s vs `on_train_batch_end` time: 0.1685s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1300 Latent Dim:  40 Batch size:  50 Annealing:  True :	 0.10494684293340234
# Recall@20 for Intermediate Dim:  1300 Latent Dim:  40 Batch size:  50 Annealing:  True :	 0.1575067301697887
# Recall@10 for Intermediate Dim:  1300 Latent Dim:  40 Batch size:  50 Annealing:  False :	 0.08152322280135822
# Recall@20 for Intermediate Dim:  1300 Latent Dim:  40 Batch size:  50 Annealing:  False :	 0.12704038757304204
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0458s vs `on_train_batch_end` time: 0.1754s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1300 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.10455377767711453
# Recall@20 for Intermediate Dim:  1300 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.1565196878098651
# Recall@10 for Intermediate Dim:  1300 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.07399350551980845
# Recall@20 for Intermediate Dim:  1300 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.11976172410630523
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0348s vs `on_train_batch_end` time: 0.1733s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1300 Latent Dim:  60 Batch size:  50 Annealing:  True :	 0.10397941762510214
# Recall@20 for Intermediate Dim:  1300 Latent Dim:  60 Batch size:  50 Annealing:  True :	 0.15597749205184794
# Recall@10 for Intermediate Dim:  1300 Latent Dim:  60 Batch size:  50 Annealing:  False :	 0.08190271186385205
# Recall@20 for Intermediate Dim:  1300 Latent Dim:  60 Batch size:  50 Annealing:  False :	 0.12204072160432099
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0401s vs `on_train_batch_end` time: 0.1888s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1300 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.10692011321014004
# Recall@20 for Intermediate Dim:  1300 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.16196865084289927
# Recall@10 for Intermediate Dim:  1300 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.07284688453254703
# Recall@20 for Intermediate Dim:  1300 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.12266029991058591
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0718s vs `on_train_batch_end` time: 0.3308s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  30 Batch size:  50 Annealing:  True :	 0.10699581183039977
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  30 Batch size:  50 Annealing:  True :	 0.16616593311891847
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  30 Batch size:  50 Annealing:  False :	 0.07173170242115266
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  30 Batch size:  50 Annealing:  False :	 0.13385775881634565
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0378s vs `on_train_batch_end` time: 0.1972s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  40 Batch size:  50 Annealing:  True :	 0.1104869666961547
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  40 Batch size:  50 Annealing:  True :	 0.16640096625812778
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  40 Batch size:  50 Annealing:  False :	 0.07651974775893404
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  40 Batch size:  50 Annealing:  False :	 0.12540542928913706
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0395s vs `on_train_batch_end` time: 0.2201s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.10829809538578936
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.15770666585902143
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.07426029667346336
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.11863079398195167
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0412s vs `on_train_batch_end` time: 0.2135s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  60 Batch size:  50 Annealing:  True :	 0.10930710544946964
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  60 Batch size:  50 Annealing:  True :	 0.15915936806038916
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  60 Batch size:  50 Annealing:  False :	 0.07609432076000296
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  60 Batch size:  50 Annealing:  False :	 0.11908671853016677
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0557s vs `on_train_batch_end` time: 0.2237s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.09987452610018147
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.16093612697327614
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.07504837813758693
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.11706887179779471
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0439s vs `on_train_batch_end` time: 0.2222s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1500 Latent Dim:  30 Batch size:  50 Annealing:  True :	 0.10922143905389287
# Recall@20 for Intermediate Dim:  1500 Latent Dim:  30 Batch size:  50 Annealing:  True :	 0.1655375405933205
# Recall@10 for Intermediate Dim:  1500 Latent Dim:  30 Batch size:  50 Annealing:  False :	 0.07858607166938891
# Recall@20 for Intermediate Dim:  1500 Latent Dim:  30 Batch size:  50 Annealing:  False :	 0.12957432392050086
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0403s vs `on_train_batch_end` time: 0.2546s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1500 Latent Dim:  40 Batch size:  50 Annealing:  True :	 0.11056880765410448
# Recall@20 for Intermediate Dim:  1500 Latent Dim:  40 Batch size:  50 Annealing:  True :	 0.15566476292640322
# Recall@10 for Intermediate Dim:  1500 Latent Dim:  40 Batch size:  50 Annealing:  False :	 0.07634265604906869
# Recall@20 for Intermediate Dim:  1500 Latent Dim:  40 Batch size:  50 Annealing:  False :	 0.12321347919262575
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0413s vs `on_train_batch_end` time: 0.2380s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1500 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.10366597821277726
# Recall@20 for Intermediate Dim:  1500 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.16789378771678343
# Recall@10 for Intermediate Dim:  1500 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.07288522103299422
# Recall@20 for Intermediate Dim:  1500 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.12382056860866998
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0420s vs `on_train_batch_end` time: 0.2415s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1500 Latent Dim:  60 Batch size:  50 Annealing:  True :	 0.10894661306184018
# Recall@20 for Intermediate Dim:  1500 Latent Dim:  60 Batch size:  50 Annealing:  True :	 0.16051329758521324
# Recall@10 for Intermediate Dim:  1500 Latent Dim:  60 Batch size:  50 Annealing:  False :	 0.07666294131393339
# Recall@20 for Intermediate Dim:  1500 Latent Dim:  60 Batch size:  50 Annealing:  False :	 0.12493643959704155
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0493s vs `on_train_batch_end` time: 0.2518s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1500 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.10743519414413098
# Recall@20 for Intermediate Dim:  1500 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.16376838320654732
# Recall@10 for Intermediate Dim:  1500 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.07612462440544815
# Recall@20 for Intermediate Dim:  1500 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.1230418095223101

# %%
# Create Dataframe out of the Results of the Hyperparameter Tuning 
df_tuning_2 = pd.DataFrame({
    "intermediate_dimensions": int_dimensions,
    "latent_dimensions": lt_dimensions,
    "annealing": anneal,
    "batch_size": batch,
    "recall@10": recall_10,
    "recall@20": recall_20,
    "precision@10":precision_10,
    "precision@20":precision_20
})
# Sort Values by recall@10 
df_tuning_2.sort_values(by='recall@10', ascending=False)
# Out:
#     intermediate_dimensions  latent_dimensions  annealing  batch_size  \
# 10                     1200                 30       True          50
# 42                     1500                 40       True          50
# 32                     1400                 40       True          50
# 36                     1400                 60       True          50
# 40                     1500                 30       True          50
# 46                     1500                 60       True          50
# 34                     1400                 50       True          50
# 0                      1100                 30       True          50
# 48                     1500                 70       True          50
# 12                     1200                 40       True          50
# 30                     1400                 30       True          50
# 2                      1100                 40       True          50
# 28                     1300                 70       True          50
# 20                     1300                 30       True          50
# 6                      1100                 60       True          50
# 16                     1200                 60       True          50
# 22                     1300                 40       True          50
# 24                     1300                 50       True          50
# 4                      1100                 50       True          50
# 26                     1300                 60       True          50
# 8                      1100                 70       True          50
# 14                     1200                 50       True          50
# 44                     1500                 50       True          50
# 18                     1200                 70       True          50
# 38                     1400                 70       True          50
# 7                      1100                 60      False          50
# 27                     1300                 60      False          50
# 23                     1300                 40      False          50
# 41                     1500                 30      False          50
# 11                     1200                 30      False          50
# 47                     1500                 60      False          50
# 9                      1100                 70      False          50
# 33                     1400                 40      False          50
# 13                     1200                 40      False          50
# 43                     1500                 40      False          50
# 17                     1200                 60      False          50
# 1                      1100                 30      False          50
# 15                     1200                 50      False          50
# 49                     1500                 70      False          50
# 37                     1400                 60      False          50
# 3                      1100                 40      False          50
# 39                     1400                 70      False          50
# 35                     1400                 50      False          50
# 25                     1300                 50      False          50
# 45                     1500                 50      False          50
# 29                     1300                 70      False          50
# 21                     1300                 30      False          50
# 19                     1200                 70      False          50
# 31                     1400                 30      False          50
# 5                      1100                 50      False          50
#
#     recall@10  recall@20  precision@10  precision@20
# 10   0.110749   0.166496      0.141067      0.113067
# 42   0.110569   0.155665      0.146667      0.112667
# 32   0.110487   0.166401      0.147600      0.115333
# 36   0.109307   0.159159      0.141200      0.112333
# 40   0.109221   0.165538      0.139733      0.113067
# 46   0.108947   0.160513      0.144667      0.112133
# 34   0.108298   0.157707      0.145467      0.113267
# 0    0.107688   0.158073      0.144933      0.112800
# 48   0.107435   0.163768      0.142533      0.114933
# 12   0.107005   0.173137      0.141200      0.117533
# 30   0.106996   0.166166      0.141067      0.113933
# 2    0.106955   0.161837      0.143467      0.112933
# 28   0.106920   0.161969      0.143067      0.112667
# 20   0.106468   0.160016      0.143200      0.112467
# 6    0.106141   0.155360      0.140800      0.112800
# 16   0.105086   0.163995      0.140800      0.114067
# 22   0.104947   0.157507      0.142133      0.110333
# 24   0.104554   0.156520      0.143067      0.112533
# 4    0.104105   0.159734      0.137333      0.109800
# 26   0.103979   0.155977      0.142133      0.110400
# 8    0.103963   0.166813      0.139600      0.114600
# 14   0.103695   0.161472      0.141867      0.115600
# 44   0.103666   0.167894      0.141467      0.115600
# 18   0.102942   0.154656      0.138267      0.108200
# 38   0.099875   0.160936      0.136400      0.111267
# 7    0.082034   0.119139      0.120133      0.092933
# 27   0.081903   0.122041      0.116800      0.092667
# 23   0.081523   0.127040      0.118533      0.097000
# 41   0.078586   0.129574      0.114000      0.097333
# 11   0.077392   0.128947      0.117067      0.096667
# 47   0.076663   0.124936      0.113467      0.095200
# 9    0.076594   0.123775      0.113733      0.091333
# 33   0.076520   0.125405      0.116133      0.096467
# 13   0.076473   0.123557      0.115600      0.093333
# 43   0.076343   0.123213      0.113867      0.094867
# 17   0.076327   0.122906      0.113333      0.093467
# 1    0.076261   0.133736      0.117067      0.097933
# 15   0.076179   0.125991      0.115200      0.093467
# 49   0.076125   0.123042      0.110667      0.091933
# 37   0.076094   0.119087      0.113600      0.092400
# 3    0.075433   0.122221      0.115200      0.093867
# 39   0.075048   0.117069      0.113333      0.090533
# 35   0.074260   0.118631      0.112533      0.090667
# 25   0.073994   0.119762      0.113733      0.091600
# 45   0.072885   0.123821      0.108933      0.093133
# 29   0.072847   0.122660      0.107467      0.092067
# 21   0.072550   0.132107      0.111733      0.099067
# 19   0.072168   0.122219      0.107600      0.090733
# 31   0.071732   0.133858      0.112533      0.098600
# 5    0.071375   0.118111      0.110800      0.092600

# %%
# Average Performance based on Intermediate Dimension
df_tuning_2[df_tuning_2['annealing']==True].groupby("intermediate_dimensions")['recall@10'].mean().sort_values(ascending=False)
# Out:
# intermediate_dimensions
# 1500    0.107968
# 1400    0.106993
# 1200    0.105895
# 1100    0.105770
# 1300    0.105374
# Name: recall@10, dtype: float64

# %%
# Average Performance based on Latent Dimension
df_tuning_2[df_tuning_2['annealing']==True].groupby("latent_dimensions")['recall@10'].mean().sort_values(ascending=False)
# Out:
# latent_dimensions
# 30    0.108224
# 40    0.107993
# 60    0.106692
# 50    0.104864
# 70    0.104227
# Name: recall@10, dtype: float64

# %%
# Average Performance based on Annealing
df_tuning_2.groupby("annealing")['recall@10'].mean().sort_values(ascending=False)
# Out:
# annealing
# True     0.106400
# False    0.075892
# Name: recall@10, dtype: float64

# %%
df_tuning_2[(df_tuning_2['intermediate_dimensions']==1200) & (df_tuning_2['annealing']==True) ].sort_values(by='recall@10',ascending=False)
# Out:
#     intermediate_dimensions  latent_dimensions  annealing  batch_size  \
# 10                     1200                 30       True          50
# 12                     1200                 40       True          50
# 16                     1200                 60       True          50
# 14                     1200                 50       True          50
# 18                     1200                 70       True          50
#
#     recall@10  recall@20  precision@10  precision@20
# 10   0.110749   0.166496      0.141067      0.113067
# 12   0.107005   0.173137      0.141200      0.117533
# 16   0.105086   0.163995      0.140800      0.114067
# 14   0.103695   0.161472      0.141867      0.115600
# 18   0.102942   0.154656      0.138267      0.108200

# %% [markdown]
# # Visualization of Hyperparameter Tuning

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(15, 12))
plt.rcParams.update({'font.size': 10})
ax = fig.add_subplot(projection='3d')

x = df_tuning_2.intermediate_dimensions
y = df_tuning_2['latent_dimensions']
z = df_tuning_2['recall@10']
annealing = df_tuning_2['annealing']

ax.set_xlabel('Intermediate Dimensions', fontname='Arial', fontsize=12)
ax.set_ylabel('Latent Dimensions', fontname='Arial', fontsize=12)
ax.set_zlabel('Recall@10', fontname='Arial', fontsize=12)

# Define different marker shapes based on the annealing values
marker_shapes = ['o', 's'] 

# Iterate over unique annealing values and plot each separately
for annealing_value in annealing.unique():
    indices = annealing == annealing_value
    ax.scatter(
        x[indices],
        y[indices],
        z[indices],
        marker=marker_shapes[annealing_value],
        s=50,
        label=f'Annealing: {annealing_value}'
    )

# Add a legend
ax.legend()

plt.show()
