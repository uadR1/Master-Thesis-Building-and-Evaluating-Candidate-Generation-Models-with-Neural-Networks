# %% [markdown]
# # Loading Libraries

# %%
# Pandas & Numpy
import pandas as pd
import numpy as np 

# Visualization
import seaborn as sns 
from matplotlib import pyplot as plt 

# Tensorflow
import tensorflow as tf
from tensorflow import keras 

# Affinity Matrix 
from recommenders.datasets.sparse import AffinityMatrix

# Evaluation 
from recommenders.evaluation.python_evaluation import (
    precision_at_k,
    recall_at_k,
    ndcg_at_k,
    map_at_k
)
from sklearn.metrics import accuracy_score 

# Recomender Utilities
from recommenders.utils.timer import Timer
from recommenders.utils.constants import SEED as DEFAULT_SEED
from recommenders.utils.python_utils import binarize
from recommenders.datasets.python_splitters import numpy_stratified_split
from recommenders.datasets.split_utils import min_rating_filter_pandas

# Multi VAE Model
from recommenders.models.vae.multinomial_vae import Mult_VAE

# System & OS
import sys
import os

# Turn of Warnings for Readability 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Import & Read Dataset

# %%
# Read Train & Test Data
train = pd.read_csv("../../00_Data/rec_sys_ratings_train.csv", index_col=0)
test = pd.read_csv("../../00_Data/rec_sys_ratings_test.csv", index_col=0)

# %%
# Check Shapes
print("Shape of Train:", train.shape)
print("Shape of Test: \t", test.shape)
# Out:
# Shape of Train: (393208, 3)
# Shape of Test: 	 (98401, 3)

# %%
# Check Number of Unique Items and User in Train & Test 
print("Unique Users in Train:", train.CustomerID.nunique())
print("Unique Users in Test:", test.CustomerID.nunique())
print("Unique Items in Train:", train.StockCode.nunique())
print("Unique Items in Test:", test.StockCode.nunique())
# Out:
# Unique Users in Train: 3011
# Unique Users in Test: 3011
# Unique Items in Train: 2318
# Unique Items in Test: 2318

# %%
# Concatenate both Dataset again for further Data Preparation
df = pd.concat([train, test], axis=0)

# %%
# Change name of columns 
df = df.rename(columns={'StockCode':'itemID', 'CustomerID':'userID', 'purchased':'rating'})
df.columns
# Out:
# Index(['itemID', 'userID', 'rating'], dtype='object')

# %% [markdown]
# # Data Filtering

# %%
# Binarize the data (only keep ratings >= 0.5)
df_preferred = df[df['rating'] > 0]
print (df_preferred.shape)
df_low_rating = df[df['rating'] <= 0]


# Head of df_preferred
df_preferred.head(10)
# Out:
# (172306, 3)
#         itemID  userID  rating
# 1750    16169E   16607       1
# 7870     20829   17888       1
# 156219  84030E   15443       1
# 101909   22810   18018       1
# 50506    22090   16774       2
# 33650    21745   13719       1
# 160104   84725   17068       1
# 61109    22281   16655       1
# 169295  85123A   14022       1
# 13204    21094   14541       1

# %%
# Head of df_low_rating
df_low_rating.head(10)
# Out:
#        itemID  userID  rating
# 444302  22326   14323      -1
# 411656  23208   15147      -1
# 302355  23301   12580      -1
# 375871  20723   12744      -1
# 309068  20719   17554      -1
# 431970  84992   18231      -1
# 438221  21790   14553      -1
# 203598   POST   14198      -2
# 295108  22457   15578      -2
# 393963  85152   16012      -1

# %%
# Keep users who clicked on at least 5 items
df = min_rating_filter_pandas(df_preferred, min_rating=5, filter_by="user")

# Keep movies that were clicked on by at least on 1 user
df = min_rating_filter_pandas(df, min_rating=1, filter_by="item")

# %%
# Obtain both usercount and itemcount after filtering
usercount = df[['userID']].groupby('userID', as_index = False).size()
itemcount = df[['itemID']].groupby('itemID', as_index = False).size()

# Compute sparsity after filtering
sparsity = 1. * df.shape[0] / (usercount.shape[0] * itemcount.shape[0])

print("After filtering, there are %d interactions between %d users and %d items (sparsity: %.3f%%)" % 
      (df.shape[0], usercount.shape[0], itemcount.shape[0], sparsity * 100))
# Out:
# After filtering, there are 172306 interactions between 3011 users and 2318 items (sparsity: 2.469%)

# %% [markdown]
# # Split Data

# %%
unique_users = sorted(df.userID.unique())
np.random.seed(1)
unique_users = np.random.permutation(unique_users)

# %%
# Create train/validation/test users
n_users = len(unique_users)
print("Number of unique users:", n_users)

train_users = unique_users[:(n_users - 602 * 2)]
print("\nNumber of training users:", len(train_users))

val_users = unique_users[(n_users - 602 * 2) : (n_users - 602)]
print("\nNumber of validation users:", len(val_users))

test_users = unique_users[(n_users - 602):]
print("\nNumber of test users:", len(test_users))
# Out:
# Number of unique users: 3011
#
# Number of training users: 1807
#
# Number of validation users: 602
#
# Number of test users: 602

# %%
# For training set keep only users that are in train_users list
train_set = df.loc[df['userID'].isin(train_users)]
print("Number of training observations: ", train_set.shape[0])

# For validation set keep only users that are in val_users list
val_set = df.loc[df['userID'].isin(val_users)]
print("\nNumber of validation observations: ", val_set.shape[0])

# For test set keep only users that are in test_users list
test_set = df.loc[df['userID'].isin(test_users)]
print("\nNumber of test observations: ", test_set.shape[0])
# Out:
# Number of training observations:  104320
#
# Number of validation observations:  34869
#
# Number of test observations:  33117

# %%
# Obtain list of unique items used in training set
unique_train_items = pd.unique(train_set['itemID'])
print("Number of unique items that consumed in training set", unique_train_items.size)
# Out:
# Number of unique items that consumed in training set 2318

# %%
# For validation set keep only items that used in training set
val_set = val_set.loc[val_set['itemID'].isin(unique_train_items)]
print("Number of validation observations after filtering: ", val_set.shape[0])

# For test set keep only movies items used in training set
test_set = test_set.loc[test_set['itemID'].isin(unique_train_items)]
print("\nNumber of test observations after filtering: ", test_set.shape[0])
# Out:
# Number of validation observations after filtering:  34869
#
# Number of test observations after filtering:  33117

# %%
test_set.shape[0] / (train_set.shape[0] + val_set.shape[0] + test_set.shape[0])
# Out:
# 0.19219876266641905

# %% [markdown]
# # Click Matrix Generation

# %%
# Instantiate the sparse matrix generation for train, validation and test sets
# use list of unique items from training set for all sets
am_train = AffinityMatrix(df=train_set, items_list=unique_train_items)

am_val = AffinityMatrix(df=val_set, items_list=unique_train_items)

am_test = AffinityMatrix(df=test_set, items_list=unique_train_items)

# %%
# Obtain the sparse matrix for train, validation and test sets
train_data, _, _ = am_train.gen_affinity_matrix()
print(train_data.shape)

val_data, val_map_users, val_map_items = am_val.gen_affinity_matrix()
print(val_data.shape)

test_data, test_map_users, test_map_items = am_test.gen_affinity_matrix()
print(test_data.shape)
# Out:
# (1807, 2318)
# (602, 2318)
# (602, 2318)

# %%
# Split validation and test data into training and testing parts
val_data_tr, val_data_te = numpy_stratified_split(val_data, ratio=0.75, seed=1)
test_data_tr, test_data_te = numpy_stratified_split(test_data, ratio=0.75, seed=1)

# %%
# Binarize train, validation and test data
train_data = binarize(a=train_data, threshold=0.5)
val_data = binarize(a=val_data, threshold=0.5)
test_data = binarize(a=test_data, threshold=0.5)

# %%
# Binarize validation data: training part  
val_data_tr = binarize(a=val_data_tr, threshold=0.5)

# Binarize validation data: testing part (save non-binary version in the separate object, will be used for calculating NDCG)
val_data_te_ratings = val_data_te.copy()
val_data_te = binarize(a=val_data_te, threshold=0.5)

# %%
# Binarize test data: training part 
test_data_tr = binarize(a=test_data_tr, threshold=0.5)

# Binarize test data: testing part (save non-binary version in the separate object, will be used for calculating NDCG)
test_data_te_ratings = test_data_te.copy()
test_data_te = binarize(a=test_data_te, threshold=0.5)

# %% [markdown]
# # Shapes & Dimensions after Data Preparation

# %%
np.unique(test_data_tr)
# Out:
# array([0., 1.])

# %%
np.unique(train_data)
# Out:
# array([0., 1.])

# %%
np.unique(val_data)
# Out:
# array([0., 1.])

# %%
np.unique(val_data_tr)
# Out:
# array([0., 1.])

# %%
np.unique(test_data_te_ratings)
# Out:
# array([0, 1, 2])

# %%
np.unique(val_data_te_ratings)
# Out:
# array([0, 1, 2])

# %% [markdown]
# # Hyperparameter Tuning

# %%
from tensorflow.python.framework.ops import disable_eager_execution

disable_eager_execution()

# %%
from tempfile import TemporaryDirectory

tmp_dir = TemporaryDirectory()
WEIGHTS_PATH = os.path.join(tmp_dir.name, "svae_weights.hdf5")

# %%
# Set up Parameters
intermediate_dimension = [600, 800, 1000, 1200, 1400] 
latent_dimension = [50, 70, 90] 
batch_sizes = [25, 50]
anneal_status = [True, False]

# Initiate Lists for Assessment
recall_10 = []
recall_20 = []
precision_10 = []
precision_20 = []
int_dimensions = []
lt_dimensions = []
anneal = []
batch = []

for i in intermediate_dimension:
    for l in latent_dimension:
        for b in batch_sizes:
            for a in anneal_status:
                try:
                    del(model)
                except:
                    pass
                
                # Initiate Model 
                if a == True:
                    model = Mult_VAE(n_users=train_data.shape[0],
                                        original_dim=train_data.shape[1],
                                        intermediate_dim=i,
                                        latent_dim=l,
                                        n_epochs=100,
                                        batch_size=b,
                                        k=100,
                                        verbose=0,
                                        seed=1,
                                        save_path=WEIGHTS_PATH,
                                        drop_encoder=0.5,
                                        drop_decoder=0.5,
                                        annealing=True,
                                        anneal_cap=1.0)
                else:
                    model = Mult_VAE(n_users=train_data.shape[0], # Number of unique users in the training set
                                        original_dim=train_data.shape[1], # Number of unique items in the training set
                                        intermediate_dim=i, 
                                        latent_dim=l, 
                                        n_epochs=100, 
                                        batch_size=b, 
                                        k=100,
                                        verbose=0,
                                        seed=1,
                                        drop_encoder=0.5,
                                        drop_decoder=0.5,
                                        annealing=False,
                                        beta=1.0,
                                        save_path=WEIGHTS_PATH)
                
                # Fit model
                model.fit(x_train=train_data,
                        x_valid=val_data,
                        x_val_tr=val_data_tr,
                        x_val_te=val_data_te_ratings,
                        mapper=am_val)
            
                # Model prediction on the training part of test set K = 10  
                top_k_10 =  model.recommend_k_items(x=test_data_tr,
                                                    k=10,
                                                    remove_seen=True)

                # Convert sparse matrix back to df
                top_k_df_10 = am_test.map_back_sparse(top_k_10, kind='prediction')
                test_df = am_test.map_back_sparse(test_data_te_ratings, kind='ratings') # use test_data_te_, with the original ratings
    

                # Use the ranking metrics for evaluation
                eval_precision_10 = precision_at_k(test_df, top_k_df_10, col_prediction='prediction', k=10)
                eval_recall_10 = recall_at_k(test_df, top_k_df_10, col_prediction='prediction', k=10)

                # Print intermediate Status for Recall@10
                print("Recall@10 for Intermediate Dim: ", i, "Latent Dim: ", l, "Batch size: ", b, "Annealing: ", a, ":\t", eval_recall_10)
                
                #Model prediction on the training part of test set K = 20  
                top_k_20 =  model.recommend_k_items(x=test_data_tr,
                                                    k=20,
                                                    remove_seen=True)

                # Convert sparse matrix back to df
                top_k_df_20 = am_test.map_back_sparse(top_k_20, kind='prediction')
    

                # Use the ranking metrics for evaluation
                eval_precision_20 = precision_at_k(test_df, top_k_df_20, col_prediction='prediction', k=20)
                eval_recall_20 = recall_at_k(test_df, top_k_df_20, col_prediction='prediction', k=20)
                
                # Print intermediate Status for Recall@20
                print("Recall@20 for Intermediate Dim: ", i, "Latent Dim: ", l, "Batch size: ", b, "Annealing: ", a, ":\t", eval_recall_20)
                
                # Append Lists
                recall_10.append(eval_recall_10)
                recall_20.append(eval_recall_20)
                precision_10.append(eval_precision_10)
                precision_20.append(eval_precision_20)
                int_dimensions.append(i)
                lt_dimensions.append(l)
                anneal.append(a)
                batch.append(b)
# Out:
# WARNING:tensorflow:From /Users/arasdirekoglu/opt/anaconda3/envs/recom/lib/python3.9/site-packages/recommenders/models/vae/multinomial_vae.py:291: The name tf.keras.initializers.truncated_normal is deprecated. Please use tf.compat.v1.keras.initializers.truncated_normal instead.
#
# WARNING:tensorflow:From /Users/arasdirekoglu/opt/anaconda3/envs/recom/lib/python3.9/site-packages/tensorflow/python/keras/initializers/initializers_v1.py:67: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 2023-06-13 14:49:44.718191: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-13 14:49:44.732843: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:196] None of the MLIR optimization passes are enabled (registered 0 passes)
# Recall@10 for Intermediate Dim:  600 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.1288896519264171
# Recall@20 for Intermediate Dim:  600 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.19890829582515485
# Recall@10 for Intermediate Dim:  600 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.09514761982941958
# Recall@20 for Intermediate Dim:  600 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.14410572243904046
# Recall@10 for Intermediate Dim:  600 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.1267015002062521
# Recall@20 for Intermediate Dim:  600 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.1926005389486811
# Recall@10 for Intermediate Dim:  600 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.08667137024377232
# Recall@20 for Intermediate Dim:  600 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.1459817989627009
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0107s vs `on_train_batch_end` time: 0.0141s). Check your callbacks.
# Recall@10 for Intermediate Dim:  600 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.13208199418658378
# Recall@20 for Intermediate Dim:  600 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.1908240435918562
# Recall@10 for Intermediate Dim:  600 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.09653001441557038
# Recall@20 for Intermediate Dim:  600 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.14844834640392354
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0159s vs `on_train_batch_end` time: 0.0199s). Check your callbacks.
# Recall@10 for Intermediate Dim:  600 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.11970422796369098
# Recall@20 for Intermediate Dim:  600 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.18003249991889805
# Recall@10 for Intermediate Dim:  600 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.09312269236281527
# Recall@20 for Intermediate Dim:  600 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.13658830780322387
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0102s vs `on_train_batch_end` time: 0.0247s). Check your callbacks.
# Recall@10 for Intermediate Dim:  600 Latent Dim:  90 Batch size:  25 Annealing:  True :	 0.11814490206791167
# Recall@20 for Intermediate Dim:  600 Latent Dim:  90 Batch size:  25 Annealing:  True :	 0.1853537018283336
# Recall@10 for Intermediate Dim:  600 Latent Dim:  90 Batch size:  25 Annealing:  False :	 0.10049261257928874
# Recall@20 for Intermediate Dim:  600 Latent Dim:  90 Batch size:  25 Annealing:  False :	 0.14442447314181958
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0163s vs `on_train_batch_end` time: 0.0311s). Check your callbacks.
# Recall@10 for Intermediate Dim:  600 Latent Dim:  90 Batch size:  50 Annealing:  True :	 0.12182001508592467
# Recall@20 for Intermediate Dim:  600 Latent Dim:  90 Batch size:  50 Annealing:  True :	 0.1802578045520228
# Recall@10 for Intermediate Dim:  600 Latent Dim:  90 Batch size:  50 Annealing:  False :	 0.09358598773093567
# Recall@20 for Intermediate Dim:  600 Latent Dim:  90 Batch size:  50 Annealing:  False :	 0.14469365932844835
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0132s vs `on_train_batch_end` time: 0.0358s). Check your callbacks.
# Recall@10 for Intermediate Dim:  800 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.13930140401977237
# Recall@20 for Intermediate Dim:  800 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.19359712057320705
# Recall@10 for Intermediate Dim:  800 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.10256267206622176
# Recall@20 for Intermediate Dim:  800 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.15418367252447646
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0195s vs `on_train_batch_end` time: 0.0409s). Check your callbacks.
# Recall@10 for Intermediate Dim:  800 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.13184721687680756
# Recall@20 for Intermediate Dim:  800 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.19922401061926384
# Recall@10 for Intermediate Dim:  800 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.09736502864854435
# Recall@20 for Intermediate Dim:  800 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.14669232224208245
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0131s vs `on_train_batch_end` time: 0.0481s). Check your callbacks.
# Recall@10 for Intermediate Dim:  800 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.13388173908354312
# Recall@20 for Intermediate Dim:  800 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.19258113536985846
# Recall@10 for Intermediate Dim:  800 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.09252871720181167
# Recall@20 for Intermediate Dim:  800 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.14707214287518558
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0227s vs `on_train_batch_end` time: 0.0560s). Check your callbacks.
# Recall@10 for Intermediate Dim:  800 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.13375939199537926
# Recall@20 for Intermediate Dim:  800 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.1942634301458551
# Recall@10 for Intermediate Dim:  800 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.09903823564117294
# Recall@20 for Intermediate Dim:  800 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.14181913204971158
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0135s vs `on_train_batch_end` time: 0.0606s). Check your callbacks.
# Recall@10 for Intermediate Dim:  800 Latent Dim:  90 Batch size:  25 Annealing:  True :	 0.13072273664911743
# Recall@20 for Intermediate Dim:  800 Latent Dim:  90 Batch size:  25 Annealing:  True :	 0.1795713482264826
# Recall@10 for Intermediate Dim:  800 Latent Dim:  90 Batch size:  25 Annealing:  False :	 0.09503040026258304
# Recall@20 for Intermediate Dim:  800 Latent Dim:  90 Batch size:  25 Annealing:  False :	 0.1483070498122757
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0203s vs `on_train_batch_end` time: 0.0658s). Check your callbacks.
# Recall@10 for Intermediate Dim:  800 Latent Dim:  90 Batch size:  50 Annealing:  True :	 0.12805269625305107
# Recall@20 for Intermediate Dim:  800 Latent Dim:  90 Batch size:  50 Annealing:  True :	 0.182508269754906
# Recall@10 for Intermediate Dim:  800 Latent Dim:  90 Batch size:  50 Annealing:  False :	 0.0923375016304078
# Recall@20 for Intermediate Dim:  800 Latent Dim:  90 Batch size:  50 Annealing:  False :	 0.1432698929077421
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0159s vs `on_train_batch_end` time: 0.0722s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.12805563742443324
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.19400165390828963
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.09391181730021894
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.13899227426112767
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0243s vs `on_train_batch_end` time: 0.0771s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.1291435463150909
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.19936177777407518
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.09552943142151905
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.15094979050878324
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0160s vs `on_train_batch_end` time: 0.0814s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.13273907512274605
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.19263062660253488
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.09393604882389968
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.1391014884629467
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0248s vs `on_train_batch_end` time: 0.0888s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.1333140120620672
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.1963342877093307
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.100563032329589
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.1432545595447769
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0161s vs `on_train_batch_end` time: 0.0955s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  90 Batch size:  25 Annealing:  True :	 0.12710304812481754
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  90 Batch size:  25 Annealing:  True :	 0.180597115199036
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  90 Batch size:  25 Annealing:  False :	 0.09797385733322979
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  90 Batch size:  25 Annealing:  False :	 0.14226236899556308
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0246s vs `on_train_batch_end` time: 0.1015s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  90 Batch size:  50 Annealing:  True :	 0.1277909776965662
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  90 Batch size:  50 Annealing:  True :	 0.18108835623572223
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  90 Batch size:  50 Annealing:  False :	 0.09415142491161921
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  90 Batch size:  50 Annealing:  False :	 0.13957270603059224
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0194s vs `on_train_batch_end` time: 0.1076s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.13456066648238785
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.192995746872351
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.09531586403713253
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.14759489813567767
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0287s vs `on_train_batch_end` time: 0.1154s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.12577657322693275
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.19511161090183746
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.09127716915528349
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.15652980127663196
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0200s vs `on_train_batch_end` time: 0.1198s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.13134106405348878
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.18965548687097702
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.09610784619232521
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.13825314872878597
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0288s vs `on_train_batch_end` time: 0.1283s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.1315793898638043
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.1952660014092183
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.09672818832732794
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.15488821814084147
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0202s vs `on_train_batch_end` time: 0.1317s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  90 Batch size:  25 Annealing:  True :	 0.12565029634534877
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  90 Batch size:  25 Annealing:  True :	 0.18427035618685575
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  90 Batch size:  25 Annealing:  False :	 0.09519788600687762
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  90 Batch size:  25 Annealing:  False :	 0.1391328125175789
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0325s vs `on_train_batch_end` time: 0.1499s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  90 Batch size:  50 Annealing:  True :	 0.13000939796130126
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  90 Batch size:  50 Annealing:  True :	 0.19592027320318084
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  90 Batch size:  50 Annealing:  False :	 0.09404307972308391
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  90 Batch size:  50 Annealing:  False :	 0.15227557110780698
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0220s vs `on_train_batch_end` time: 0.1448s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.13691509638756633
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.19724643974723172
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.09674429388936043
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.14510527555995612
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0332s vs `on_train_batch_end` time: 0.1500s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.13427154218621595
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  50 Batch size:  50 Annealing:  True :	 0.1979612234751325
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.09380639925067503
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  50 Batch size:  50 Annealing:  False :	 0.15996647849919995
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0227s vs `on_train_batch_end` time: 0.1554s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.12833308868165927
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.19061647251566263
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.08982731238121976
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.13596173440461326
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0340s vs `on_train_batch_end` time: 0.1657s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.13222136176863375
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  70 Batch size:  50 Annealing:  True :	 0.1861133041771097
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.10992609267673967
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  70 Batch size:  50 Annealing:  False :	 0.1508276167838641
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0231s vs `on_train_batch_end` time: 0.1712s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  90 Batch size:  25 Annealing:  True :	 0.12733590354836644
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  90 Batch size:  25 Annealing:  True :	 0.1869076318383385
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  90 Batch size:  25 Annealing:  False :	 0.09094634393327453
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  90 Batch size:  25 Annealing:  False :	 0.1446006946871403
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0339s vs `on_train_batch_end` time: 0.1778s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  90 Batch size:  50 Annealing:  True :	 0.12830300067753786
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  90 Batch size:  50 Annealing:  True :	 0.17508883645431442
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  90 Batch size:  50 Annealing:  False :	 0.08997261438361302
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  90 Batch size:  50 Annealing:  False :	 0.13424433723202972

# %%
# Create Dataframe out of the Results of the Hyperparameter Tuning 
df_tuning_initial = pd.DataFrame({
    "intermediate_dimensions": int_dimensions,
    "latent_dimensions": lt_dimensions,
    "annealing": anneal,
    "batch_size": batch,
    "recall@10": recall_10,
    "recall@20": recall_20,
    "precision@10":precision_10,
    "precision@20":precision_20
})
# Sort Values by recall@10 
df_tuning_initial.sort_values(by='recall@10', ascending=False)
# Out:
#     intermediate_dimensions  latent_dimensions  annealing  batch_size  \
# 12                      800                 50       True          25
# 48                     1400                 50       True          25
# 36                     1200                 50       True          25
# 50                     1400                 50       True          50
# 16                      800                 70       True          25
# 18                      800                 70       True          50
# 30                     1000                 70       True          50
# 28                     1000                 70       True          25
# 54                     1400                 70       True          50
# 4                       600                 70       True          25
# 14                      800                 50       True          50
# 42                     1200                 70       True          50
# 40                     1200                 70       True          25
# 20                      800                 90       True          25
# 46                     1200                 90       True          50
# 26                     1000                 50       True          50
# 0                       600                 50       True          25
# 52                     1400                 70       True          25
# 58                     1400                 90       True          50
# 24                     1000                 50       True          25
# 22                      800                 90       True          50
# 34                     1000                 90       True          50
# 56                     1400                 90       True          25
# 32                     1000                 90       True          25
# 2                       600                 50       True          50
# 38                     1200                 50       True          50
# 44                     1200                 90       True          25
# 10                      600                 90       True          50
# 6                       600                 70       True          50
# 8                       600                 90       True          25
# 55                     1400                 70      False          50
# 13                      800                 50      False          25
# 31                     1000                 70      False          50
# 9                       600                 90      False          25
# 19                      800                 70      False          50
# 33                     1000                 90      False          25
# 15                      800                 50      False          50
# 49                     1400                 50      False          25
# 43                     1200                 70      False          50
# 5                       600                 70      False          25
# 41                     1200                 70      False          25
# 27                     1000                 50      False          50
# 37                     1200                 50      False          25
# 45                     1200                 90      False          25
# 1                       600                 50      False          25
# 21                      800                 90      False          25
# 35                     1000                 90      False          50
# 47                     1200                 90      False          50
# 29                     1000                 70      False          25
# 25                     1000                 50      False          25
# 51                     1400                 50      False          50
# 11                      600                 90      False          50
# 7                       600                 70      False          50
# 17                      800                 70      False          25
# 23                      800                 90      False          50
# 39                     1200                 50      False          50
# 57                     1400                 90      False          25
# 59                     1400                 90      False          50
# 53                     1400                 70      False          25
# 3                       600                 50      False          50
#
#     recall@10  recall@20  precision@10  precision@20
# 12   0.139301   0.193597      0.150332      0.112292
# 48   0.136915   0.197246      0.151495      0.115698
# 36   0.134561   0.192996      0.146179      0.110963
# 50   0.134272   0.197961      0.150166      0.113455
# 16   0.133882   0.192581      0.144850      0.110631
# 18   0.133759   0.194263      0.144352      0.109635
# 30   0.133314   0.196334      0.144352      0.111379
# 28   0.132739   0.192631      0.147342      0.111960
# 54   0.132221   0.186113      0.145183      0.109136
# 4    0.132082   0.190824      0.144352      0.111130
# 14   0.131847   0.199224      0.144352      0.114369
# 42   0.131579   0.195266      0.146844      0.110714
# 40   0.131341   0.189655      0.144352      0.108721
# 20   0.130723   0.179571      0.143688      0.107309
# 46   0.130009   0.195920      0.143688      0.112791
# 26   0.129144   0.199362      0.140864      0.114203
# 0    0.128890   0.198908      0.141362      0.112043
# 52   0.128333   0.190616      0.145017      0.110465
# 58   0.128303   0.175089      0.142691      0.106811
# 24   0.128056   0.194002      0.146179      0.111296
# 22   0.128053   0.182508      0.140532      0.106728
# 34   0.127791   0.181088      0.140864      0.106811
# 56   0.127336   0.186908      0.142193      0.108970
# 32   0.127103   0.180597      0.142525      0.108721
# 2    0.126702   0.192601      0.145515      0.111545
# 38   0.125777   0.195112      0.143854      0.112957
# 44   0.125650   0.184270      0.141196      0.109136
# 10   0.121820   0.180258      0.136379      0.106229
# 6    0.119704   0.180032      0.131894      0.103239
# 8    0.118145   0.185354      0.132558      0.104485
# 55   0.109926   0.150828      0.124086      0.091030
# 13   0.102563   0.154184      0.116611      0.091528
# 31   0.100563   0.143255      0.113123      0.088372
# 9    0.100493   0.144424      0.115116      0.086711
# 19   0.099038   0.141819      0.115781      0.087625
# 33   0.097974   0.142262      0.112292      0.087791
# 15   0.097365   0.146692      0.111794      0.089452
# 49   0.096744   0.145105      0.117774      0.087957
# 43   0.096728   0.154888      0.116445      0.090365
# 5    0.096530   0.148448      0.120100      0.092110
# 41   0.096108   0.138253      0.115781      0.084967
# 27   0.095529   0.150950      0.112791      0.090449
# 37   0.095316   0.147595      0.115449      0.092110
# 45   0.095198   0.139133      0.114286      0.086628
# 1    0.095148   0.144106      0.113289      0.087458
# 21   0.095030   0.148307      0.113123      0.088538
# 35   0.094151   0.139573      0.110299      0.085631
# 47   0.094043   0.152276      0.110299      0.093106
# 29   0.093936   0.139101      0.114950      0.085382
# 25   0.093912   0.138992      0.107973      0.086130
# 51   0.093806   0.159966      0.111130      0.097010
# 11   0.093586   0.144694      0.108472      0.086960
# 7    0.093123   0.136588      0.111628      0.083223
# 17   0.092529   0.147072      0.115116      0.090033
# 23   0.092338   0.143270      0.107309      0.086545
# 39   0.091277   0.156530      0.111794      0.093106
# 57   0.090946   0.144601      0.109801      0.089950
# 59   0.089973   0.134244      0.106811      0.086628
# 53   0.089827   0.135962      0.111960      0.085548
# 3    0.086671   0.145982      0.104319      0.086711

# %%
# Check Average Performance of Latent Dimensions
df_tuning_initial.groupby("latent_dimensions")['recall@10'].mean()
# Out:
# latent_dimensions
# 50    0.087695
# 70    0.080740
# 90    0.078705
# Name: recall@10, dtype: float64

# %% [markdown]
# # Hyperparameter Tuning 2.0

# %%
# Set up Parameters
intermediate_dimension = [700, 800, 900, 1000, 1100, 1200, 1300, 1400] 
latent_dimension = [30, 40, 50, 60, 70] 
batch_sizes = [25]
anneal_status = [True, False]

# Initiate Lists for Assessment
recall_10 = []
recall_20 = []
precision_10 = []
precision_20 = []
int_dimensions = []
lt_dimensions = []
anneal = []
batch = []

for i in intermediate_dimension:
    for l in latent_dimension:
        for b in batch_sizes:
            for a in anneal_status:
                try:
                    del(model)
                except:
                    pass
                
                # Initiate Model 
                if a == True:
                    model = Mult_VAE(n_users=train_data.shape[0],
                                        original_dim=train_data.shape[1],
                                        intermediate_dim=i,
                                        latent_dim=l,
                                        n_epochs=100,
                                        batch_size=b,
                                        k=100,
                                        verbose=0,
                                        seed=1,
                                        save_path=WEIGHTS_PATH,
                                        drop_encoder=0.5,
                                        drop_decoder=0.5,
                                        annealing=True,
                                        anneal_cap=1.0)
                else:
                    model = Mult_VAE(n_users=train_data.shape[0], # Number of unique users in the training set
                                        original_dim=train_data.shape[1], # Number of unique items in the training set
                                        intermediate_dim=i, 
                                        latent_dim=l, 
                                        n_epochs=100, 
                                        batch_size=b, 
                                        k=100,
                                        verbose=0,
                                        seed=1,
                                        drop_encoder=0.5,
                                        drop_decoder=0.5,
                                        annealing=False,
                                        beta=1.0,
                                        save_path=WEIGHTS_PATH)
                
                # Fit model
                model.fit(x_train=train_data,
                        x_valid=val_data,
                        x_val_tr=val_data_tr,
                        x_val_te=val_data_te_ratings,
                        mapper=am_val)
            
                # Model prediction on the training part of test set K = 10  
                top_k_10 =  model.recommend_k_items(x=test_data_tr,
                                                    k=10,
                                                    remove_seen=True)

                # Convert sparse matrix back to df
                top_k_df_10 = am_test.map_back_sparse(top_k_10, kind='prediction')
                test_df = am_test.map_back_sparse(test_data_te_ratings, kind='ratings') # use test_data_te_, with the original ratings
    

                # Use the ranking metrics for evaluation
                eval_precision_10 = precision_at_k(test_df, top_k_df_10, col_prediction='prediction', k=10)
                eval_recall_10 = recall_at_k(test_df, top_k_df_10, col_prediction='prediction', k=10)

                # Print intermediate Status for Recall@10
                print("Recall@10 for Intermediate Dim: ", i, "Latent Dim: ", l, "Batch size: ", b, "Annealing: ", a, ":\t", eval_recall_10)
                
                #Model prediction on the training part of test set K = 20  
                top_k_20 =  model.recommend_k_items(x=test_data_tr,
                                                    k=20,
                                                    remove_seen=True)

                # Convert sparse matrix back to df
                top_k_df_20 = am_test.map_back_sparse(top_k_20, kind='prediction')
    

                # Use the ranking metrics for evaluation
                eval_precision_20 = precision_at_k(test_df, top_k_df_20, col_prediction='prediction', k=20)
                eval_recall_20 = recall_at_k(test_df, top_k_df_20, col_prediction='prediction', k=20)
                
                # Print intermediate Status for Recall@20
                print("Recall@20 for Intermediate Dim: ", i, "Latent Dim: ", l, "Batch size: ", b, "Annealing: ", a, ":\t", eval_recall_20)
                
                # Append Lists
                recall_10.append(eval_recall_10)
                recall_20.append(eval_recall_20)
                precision_10.append(eval_precision_10)
                precision_20.append(eval_precision_20)
                int_dimensions.append(i)
                lt_dimensions.append(l)
                anneal.append(a)
                batch.append(b)
# Out:
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0132s vs `on_train_batch_end` time: 0.1824s). Check your callbacks.
# Recall@10 for Intermediate Dim:  700 Latent Dim:  30 Batch size:  25 Annealing:  True :	 0.13714303190757274
# Recall@20 for Intermediate Dim:  700 Latent Dim:  30 Batch size:  25 Annealing:  True :	 0.1966299590344378
# Recall@10 for Intermediate Dim:  700 Latent Dim:  30 Batch size:  25 Annealing:  False :	 0.09945720553249796
# Recall@20 for Intermediate Dim:  700 Latent Dim:  30 Batch size:  25 Annealing:  False :	 0.15480810999857328
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0124s vs `on_train_batch_end` time: 0.1828s). Check your callbacks.
# Recall@10 for Intermediate Dim:  700 Latent Dim:  40 Batch size:  25 Annealing:  True :	 0.1367063394430854
# Recall@20 for Intermediate Dim:  700 Latent Dim:  40 Batch size:  25 Annealing:  True :	 0.19668945725466783
# Recall@10 for Intermediate Dim:  700 Latent Dim:  40 Batch size:  25 Annealing:  False :	 0.09360783796085347
# Recall@20 for Intermediate Dim:  700 Latent Dim:  40 Batch size:  25 Annealing:  False :	 0.14043207144036088
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0127s vs `on_train_batch_end` time: 0.1929s). Check your callbacks.
# Recall@10 for Intermediate Dim:  700 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.13653636135374952
# Recall@20 for Intermediate Dim:  700 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.19912072022002864
# Recall@10 for Intermediate Dim:  700 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.10007146128791533
# Recall@20 for Intermediate Dim:  700 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.14828628343412784
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0128s vs `on_train_batch_end` time: 0.1982s). Check your callbacks.
# Recall@10 for Intermediate Dim:  700 Latent Dim:  60 Batch size:  25 Annealing:  True :	 0.12870784575223262
# Recall@20 for Intermediate Dim:  700 Latent Dim:  60 Batch size:  25 Annealing:  True :	 0.1958718574161412
# Recall@10 for Intermediate Dim:  700 Latent Dim:  60 Batch size:  25 Annealing:  False :	 0.09459001293411538
# Recall@20 for Intermediate Dim:  700 Latent Dim:  60 Batch size:  25 Annealing:  False :	 0.14541166821087967
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0126s vs `on_train_batch_end` time: 0.2050s). Check your callbacks.
# Recall@10 for Intermediate Dim:  700 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.13300813524719607
# Recall@20 for Intermediate Dim:  700 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.19356823460069697
# Recall@10 for Intermediate Dim:  700 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.09673676352754028
# Recall@20 for Intermediate Dim:  700 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.139925919533918
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0133s vs `on_train_batch_end` time: 0.2075s). Check your callbacks.
# Recall@10 for Intermediate Dim:  800 Latent Dim:  30 Batch size:  25 Annealing:  True :	 0.12967289719766173
# Recall@20 for Intermediate Dim:  800 Latent Dim:  30 Batch size:  25 Annealing:  True :	 0.19289352735476595
# Recall@10 for Intermediate Dim:  800 Latent Dim:  30 Batch size:  25 Annealing:  False :	 0.103463483621712
# Recall@20 for Intermediate Dim:  800 Latent Dim:  30 Batch size:  25 Annealing:  False :	 0.15616971468361063
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0135s vs `on_train_batch_end` time: 0.2124s). Check your callbacks.
# Recall@10 for Intermediate Dim:  800 Latent Dim:  40 Batch size:  25 Annealing:  True :	 0.1267073809142722
# Recall@20 for Intermediate Dim:  800 Latent Dim:  40 Batch size:  25 Annealing:  True :	 0.19551000453584136
# Recall@10 for Intermediate Dim:  800 Latent Dim:  40 Batch size:  25 Annealing:  False :	 0.09879095388965403
# Recall@20 for Intermediate Dim:  800 Latent Dim:  40 Batch size:  25 Annealing:  False :	 0.1516250973145155
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0135s vs `on_train_batch_end` time: 0.2222s). Check your callbacks.
# Recall@10 for Intermediate Dim:  800 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.13463982071104
# Recall@20 for Intermediate Dim:  800 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.19782913582370149
# Recall@10 for Intermediate Dim:  800 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.09428358155664054
# Recall@20 for Intermediate Dim:  800 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.1474243434021565
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0139s vs `on_train_batch_end` time: 0.2298s). Check your callbacks.
# Recall@10 for Intermediate Dim:  800 Latent Dim:  60 Batch size:  25 Annealing:  True :	 0.1354326684830894
# Recall@20 for Intermediate Dim:  800 Latent Dim:  60 Batch size:  25 Annealing:  True :	 0.19649454137045702
# Recall@10 for Intermediate Dim:  800 Latent Dim:  60 Batch size:  25 Annealing:  False :	 0.08647626108579298
# Recall@20 for Intermediate Dim:  800 Latent Dim:  60 Batch size:  25 Annealing:  False :	 0.14189688056028724
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0143s vs `on_train_batch_end` time: 0.2343s). Check your callbacks.
# Recall@10 for Intermediate Dim:  800 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.13055942275356502
# Recall@20 for Intermediate Dim:  800 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.1839191353568467
# Recall@10 for Intermediate Dim:  800 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.09192567333188399
# Recall@20 for Intermediate Dim:  800 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.1463091003119458
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0150s vs `on_train_batch_end` time: 0.2357s). Check your callbacks.
# Recall@10 for Intermediate Dim:  900 Latent Dim:  30 Batch size:  25 Annealing:  True :	 0.13467360591409844
# Recall@20 for Intermediate Dim:  900 Latent Dim:  30 Batch size:  25 Annealing:  True :	 0.19549257836217498
# Recall@10 for Intermediate Dim:  900 Latent Dim:  30 Batch size:  25 Annealing:  False :	 0.10665622633415485
# Recall@20 for Intermediate Dim:  900 Latent Dim:  30 Batch size:  25 Annealing:  False :	 0.14801490696720435
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0152s vs `on_train_batch_end` time: 0.2452s). Check your callbacks.
# Recall@10 for Intermediate Dim:  900 Latent Dim:  40 Batch size:  25 Annealing:  True :	 0.13222951761264873
# Recall@20 for Intermediate Dim:  900 Latent Dim:  40 Batch size:  25 Annealing:  True :	 0.20190382883135563
# Recall@10 for Intermediate Dim:  900 Latent Dim:  40 Batch size:  25 Annealing:  False :	 0.09426518413149776
# Recall@20 for Intermediate Dim:  900 Latent Dim:  40 Batch size:  25 Annealing:  False :	 0.15129162073647237
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0154s vs `on_train_batch_end` time: 0.2536s). Check your callbacks.
# Recall@10 for Intermediate Dim:  900 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.13323605692037835
# Recall@20 for Intermediate Dim:  900 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.19568343408618571
# Recall@10 for Intermediate Dim:  900 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.10002119605171164
# Recall@20 for Intermediate Dim:  900 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.15766869330821903
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0157s vs `on_train_batch_end` time: 0.2655s). Check your callbacks.
# Recall@10 for Intermediate Dim:  900 Latent Dim:  60 Batch size:  25 Annealing:  True :	 0.13807367257700373
# Recall@20 for Intermediate Dim:  900 Latent Dim:  60 Batch size:  25 Annealing:  True :	 0.19553339807828465
# Recall@10 for Intermediate Dim:  900 Latent Dim:  60 Batch size:  25 Annealing:  False :	 0.09376187481591376
# Recall@20 for Intermediate Dim:  900 Latent Dim:  60 Batch size:  25 Annealing:  False :	 0.1482182943208824
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0157s vs `on_train_batch_end` time: 0.2629s). Check your callbacks.
# Recall@10 for Intermediate Dim:  900 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.1290261503077773
# Recall@20 for Intermediate Dim:  900 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.18291235667081437
# Recall@10 for Intermediate Dim:  900 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.08987338339488646
# Recall@20 for Intermediate Dim:  900 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.14121590228812866
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0172s vs `on_train_batch_end` time: 0.2763s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  30 Batch size:  25 Annealing:  True :	 0.14111442281139897
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  30 Batch size:  25 Annealing:  True :	 0.20033156062805701
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  30 Batch size:  25 Annealing:  False :	 0.10090904344348336
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  30 Batch size:  25 Annealing:  False :	 0.15827146324854033
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0170s vs `on_train_batch_end` time: 0.2744s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  40 Batch size:  25 Annealing:  True :	 0.13517582465939826
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  40 Batch size:  25 Annealing:  True :	 0.19626281677598023
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  40 Batch size:  25 Annealing:  False :	 0.09728416924672269
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  40 Batch size:  25 Annealing:  False :	 0.15444152244130174
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0171s vs `on_train_batch_end` time: 0.2892s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.13590515901832587
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.19749270831556004
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.09582303028615305
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.15173383305987856
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0172s vs `on_train_batch_end` time: 0.2872s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  60 Batch size:  25 Annealing:  True :	 0.13648814105898818
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  60 Batch size:  25 Annealing:  True :	 0.20062856119290565
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  60 Batch size:  25 Annealing:  False :	 0.0940645673486889
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  60 Batch size:  25 Annealing:  False :	 0.14557657661391712
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0173s vs `on_train_batch_end` time: 0.2978s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.13759863822763288
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.192840850819369
# Recall@10 for Intermediate Dim:  1000 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.09499124227694872
# Recall@20 for Intermediate Dim:  1000 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.1411335421033822
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0189s vs `on_train_batch_end` time: 0.3079s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1100 Latent Dim:  30 Batch size:  25 Annealing:  True :	 0.13060135905280404
# Recall@20 for Intermediate Dim:  1100 Latent Dim:  30 Batch size:  25 Annealing:  True :	 0.19616475193745814
# Recall@10 for Intermediate Dim:  1100 Latent Dim:  30 Batch size:  25 Annealing:  False :	 0.10236196861165653
# Recall@20 for Intermediate Dim:  1100 Latent Dim:  30 Batch size:  25 Annealing:  False :	 0.14597450137418888
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0186s vs `on_train_batch_end` time: 0.3128s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1100 Latent Dim:  40 Batch size:  25 Annealing:  True :	 0.13523567346490833
# Recall@20 for Intermediate Dim:  1100 Latent Dim:  40 Batch size:  25 Annealing:  True :	 0.1967508813993829
# Recall@10 for Intermediate Dim:  1100 Latent Dim:  40 Batch size:  25 Annealing:  False :	 0.09612377597568202
# Recall@20 for Intermediate Dim:  1100 Latent Dim:  40 Batch size:  25 Annealing:  False :	 0.15129704129309537
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0187s vs `on_train_batch_end` time: 0.3193s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1100 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.13291027518880694
# Recall@20 for Intermediate Dim:  1100 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.19690472177813179
# Recall@10 for Intermediate Dim:  1100 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.09580188163720736
# Recall@20 for Intermediate Dim:  1100 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.15565914050303084
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0191s vs `on_train_batch_end` time: 0.3226s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1100 Latent Dim:  60 Batch size:  25 Annealing:  True :	 0.13340929951917888
# Recall@20 for Intermediate Dim:  1100 Latent Dim:  60 Batch size:  25 Annealing:  True :	 0.18677561547043647
# Recall@10 for Intermediate Dim:  1100 Latent Dim:  60 Batch size:  25 Annealing:  False :	 0.09286337349887057
# Recall@20 for Intermediate Dim:  1100 Latent Dim:  60 Batch size:  25 Annealing:  False :	 0.14069388905659597
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0191s vs `on_train_batch_end` time: 0.3295s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1100 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.13092313974884276
# Recall@20 for Intermediate Dim:  1100 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.19393110575833183
# Recall@10 for Intermediate Dim:  1100 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.09266449136899284
# Recall@20 for Intermediate Dim:  1100 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.14567942960148197
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0207s vs `on_train_batch_end` time: 0.3365s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  30 Batch size:  25 Annealing:  True :	 0.14016803813388945
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  30 Batch size:  25 Annealing:  True :	 0.19712344299532344
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  30 Batch size:  25 Annealing:  False :	 0.10041688584012803
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  30 Batch size:  25 Annealing:  False :	 0.15462064083353325
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0208s vs `on_train_batch_end` time: 0.3423s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  40 Batch size:  25 Annealing:  True :	 0.1346946321054422
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  40 Batch size:  25 Annealing:  True :	 0.19635872038388857
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  40 Batch size:  25 Annealing:  False :	 0.09119457098862226
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  40 Batch size:  25 Annealing:  False :	 0.14714340277634974
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0213s vs `on_train_batch_end` time: 0.3515s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.1366193495776213
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.19676856928121952
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.09150445881750206
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.14696684085401124
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0228s vs `on_train_batch_end` time: 0.3566s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  60 Batch size:  25 Annealing:  True :	 0.13400492160829844
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  60 Batch size:  25 Annealing:  True :	 0.19795421997014706
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  60 Batch size:  25 Annealing:  False :	 0.0949220904473665
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  60 Batch size:  25 Annealing:  False :	 0.14489985731368676
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0213s vs `on_train_batch_end` time: 0.3614s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.13247454250035656
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.18913478082344884
# Recall@10 for Intermediate Dim:  1200 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.08998073354219446
# Recall@20 for Intermediate Dim:  1200 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.1479395511840714
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0220s vs `on_train_batch_end` time: 0.3627s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1300 Latent Dim:  30 Batch size:  25 Annealing:  True :	 0.13553910949733786
# Recall@20 for Intermediate Dim:  1300 Latent Dim:  30 Batch size:  25 Annealing:  True :	 0.2042012409547549
# Recall@10 for Intermediate Dim:  1300 Latent Dim:  30 Batch size:  25 Annealing:  False :	 0.09948867403450537
# Recall@20 for Intermediate Dim:  1300 Latent Dim:  30 Batch size:  25 Annealing:  False :	 0.15257613182618276
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0216s vs `on_train_batch_end` time: 0.3755s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1300 Latent Dim:  40 Batch size:  25 Annealing:  True :	 0.13673956160268633
# Recall@20 for Intermediate Dim:  1300 Latent Dim:  40 Batch size:  25 Annealing:  True :	 0.19673344370405355
# Recall@10 for Intermediate Dim:  1300 Latent Dim:  40 Batch size:  25 Annealing:  False :	 0.10050164657719772
# Recall@20 for Intermediate Dim:  1300 Latent Dim:  40 Batch size:  25 Annealing:  False :	 0.15389777256439321
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0219s vs `on_train_batch_end` time: 0.3793s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1300 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.13550866887813948
# Recall@20 for Intermediate Dim:  1300 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.18968626787213722
# Recall@10 for Intermediate Dim:  1300 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.09363775565584374
# Recall@20 for Intermediate Dim:  1300 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.15279440195387708
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0220s vs `on_train_batch_end` time: 0.3855s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1300 Latent Dim:  60 Batch size:  25 Annealing:  True :	 0.12938585039584877
# Recall@20 for Intermediate Dim:  1300 Latent Dim:  60 Batch size:  25 Annealing:  True :	 0.20243750905993255
# Recall@10 for Intermediate Dim:  1300 Latent Dim:  60 Batch size:  25 Annealing:  False :	 0.09377430409200499
# Recall@20 for Intermediate Dim:  1300 Latent Dim:  60 Batch size:  25 Annealing:  False :	 0.1396109009891557
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0222s vs `on_train_batch_end` time: 0.3990s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1300 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.13267176205064468
# Recall@20 for Intermediate Dim:  1300 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.19602168189807156
# Recall@10 for Intermediate Dim:  1300 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.09322865428113683
# Recall@20 for Intermediate Dim:  1300 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.14034565371564237
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0234s vs `on_train_batch_end` time: 0.4029s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  30 Batch size:  25 Annealing:  True :	 0.13509768223305754
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  30 Batch size:  25 Annealing:  True :	 0.19510266308607582
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  30 Batch size:  25 Annealing:  False :	 0.0990203705692241
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  30 Batch size:  25 Annealing:  False :	 0.1492921292027841
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0237s vs `on_train_batch_end` time: 0.4116s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  40 Batch size:  25 Annealing:  True :	 0.1308692485712853
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  40 Batch size:  25 Annealing:  True :	 0.194856985873368
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  40 Batch size:  25 Annealing:  False :	 0.09263291903746777
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  40 Batch size:  25 Annealing:  False :	 0.1470342594322423
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0235s vs `on_train_batch_end` time: 0.4140s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.12743710301802616
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  50 Batch size:  25 Annealing:  True :	 0.19524900808696657
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.09790373780975277
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  50 Batch size:  25 Annealing:  False :	 0.1539339388642414
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0238s vs `on_train_batch_end` time: 0.4241s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  60 Batch size:  25 Annealing:  True :	 0.132044149380229
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  60 Batch size:  25 Annealing:  True :	 0.1974746369982287
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  60 Batch size:  25 Annealing:  False :	 0.09481002229786648
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  60 Batch size:  25 Annealing:  False :	 0.13881132365977045
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0249s vs `on_train_batch_end` time: 0.4328s). Check your callbacks.
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.12727210038248335
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  70 Batch size:  25 Annealing:  True :	 0.19035954167234642
# Recall@10 for Intermediate Dim:  1400 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.0931120379908613
# Recall@20 for Intermediate Dim:  1400 Latent Dim:  70 Batch size:  25 Annealing:  False :	 0.14138406058398328

# %%
# Create Dataframe out of the Results of the Hyperparameter Tuning 
df_tuning_2 = pd.DataFrame({
    "intermediate_dimensions": int_dimensions,
    "latent_dimensions": lt_dimensions,
    "annealing": anneal,
    "batch_size": batch,
    "recall@10": recall_10,
    "recall@20": recall_20,
    "precision@10":precision_10,
    "precision@20":precision_20
})
# Sort Values by recall@10 
df_tuning_2.sort_values(by='recall@10', ascending=False)
# Out:
#     intermediate_dimensions  latent_dimensions  annealing  batch_size  \
# 30                     1000                 30       True          25
# 50                     1200                 30       True          25
# 26                      900                 60       True          25
# 38                     1000                 70       True          25
# 0                       700                 30       True          25
# ..                      ...                ...        ...         ...
# 55                     1200                 50      False          25
# 53                     1200                 40      False          25
# 59                     1200                 70      False          25
# 29                      900                 70      False          25
# 17                      800                 60      False          25
#
#     recall@10  recall@20  precision@10  precision@20
# 30   0.141114   0.200332      0.151329      0.112375
# 50   0.140168   0.197123      0.150332      0.111213
# 26   0.138074   0.195533      0.150332      0.113123
# 38   0.137599   0.192841      0.150000      0.111711
# 0    0.137143   0.196630      0.150997      0.112043
# ..        ...        ...           ...           ...
# 55   0.091504   0.146967      0.108472      0.090116
# 53   0.091195   0.147143      0.113787      0.091113
# 59   0.089981   0.147940      0.111794      0.090033
# 29   0.089873   0.141216      0.110631      0.086960
# 17   0.086476   0.141897      0.111462      0.089037
#
# [80 rows x 8 columns]

# %%
# Impact of Annealing on Recall@10
df_tuning_2.groupby("annealing")['recall@10'].mean().sort_values(ascending=False)
# Out:
# annealing
# True     0.133656
# False    0.095825
# Name: recall@10, dtype: float64

# %%
# Difference Average Recall@10 between Annealing & Non-Annealing
df_tuning_2.groupby("annealing")['recall@10'].mean().sort_values(ascending=False)[0] - df_tuning_2.groupby("annealing")['recall@10'].mean().sort_values(ascending=False)[1]
# Out:
# 0.03783110136620381

# %%
# Impact of Intermediate Dimensions
df_tuning_2.groupby('intermediate_dimensions')['recall@10'].mean().sort_values(ascending=False)
# Out:
# intermediate_dimensions
# 1000    0.116935
# 700     0.115656
# 900     0.115182
# 1300    0.115048
# 1200    0.114598
# 1100    0.114290
# 800     0.113195
# 1400    0.113020
# Name: recall@10, dtype: float64

# %%
# Impact of Intermediate Dimensions with Annealing
df_tuning_2[df_tuning_2['annealing']==True].groupby('intermediate_dimensions')['recall@10'].mean().sort_values(ascending=False)
# Out:
# intermediate_dimensions
# 1000    0.137256
# 1200    0.135592
# 700     0.134420
# 1300    0.133969
# 900     0.133448
# 1100    0.132616
# 800     0.131402
# 1400    0.130544
# Name: recall@10, dtype: float64

# %%
# Impact of Latent Dimensions
df_tuning_2.groupby('latent_dimensions')['recall@10'].mean().sort_values(ascending=False)
# Out:
# latent_dimensions
# 30    0.118487
# 50    0.115115
# 40    0.114547
# 60    0.113301
# 70    0.112253
# Name: recall@10, dtype: float64

# %%
# Impact of Latent Dimensions with Annealing 
df_tuning_2[df_tuning_2['annealing']==True].groupby('latent_dimensions')['recall@10'].mean().sort_values(ascending=False)
# Out:
# latent_dimensions
# 30    0.135501
# 50    0.134099
# 40    0.133545
# 60    0.133443
# 70    0.131692
# Name: recall@10, dtype: float64

# %% [markdown]
# # Visualization of Hyperparameter Tuning

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(15, 12))
plt.rcParams.update({'font.size': 10})
ax = fig.add_subplot(projection='3d')

x = df_tuning_2.intermediate_dimensions
y = df_tuning_2['latent_dimensions']
z = df_tuning_2['recall@10']
annealing = df_tuning_2['annealing']

ax.set_xlabel('Intermediate Dimensions', fontname='Arial', fontsize=12)
ax.set_ylabel('Latent Dimensions', fontname='Arial', fontsize=12)
ax.set_zlabel('Recall@10', fontname='Arial', fontsize=12)

# Define different marker shapes based on the annealing values
marker_shapes = ['o', 's'] 

# Iterate over unique annealing values and plot each separately
for annealing_value in annealing.unique():
    indices = annealing == annealing_value
    ax.scatter(
        x[indices],
        y[indices],
        z[indices],
        marker=marker_shapes[annealing_value],
        s=50,
        label=f'Annealing: {annealing_value}'
    )

# Add a legend
ax.legend()

plt.show()
